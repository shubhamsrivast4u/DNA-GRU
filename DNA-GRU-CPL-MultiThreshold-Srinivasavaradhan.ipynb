# %% [markdown]
# # DNA Storage Pipeline: Train DNN + Multi-Threshold CPL Analysis
#
# Unified: Training, DNN Evaluation, CPL correction with multiple thresholds.
# Change `DATASET_NAME` and `RUN_MODE` to control behavior.
#
# **Key features:**
# - Auto-detects `clustersizethreshold` using DNAformer's methodology
# - Sweeps multiple CPL percentile thresholds (p0..p25)
# - Generates paper-ready figures + .mat files for MATLAB
# - Multi-run variance analysis for DNN inference

# %%
# =============================================================================
# IMPORTS
# =============================================================================

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from pathlib import Path
import os
import numpy as np
from tqdm.notebook import tqdm
import random
import time
import pandas as pd
import math
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib
import scipy.io as sio
matplotlib.rcParams.update({
    'font.size': 12, 'axes.titlesize': 14, 'axes.labelsize': 12,
    'xtick.labelsize': 10, 'ytick.labelsize': 10, 'legend.fontsize': 10,
    'figure.dpi': 150, 'savefig.dpi': 300, 'savefig.bbox': 'tight',
    'font.family': 'serif',
})

os.environ["CUDA_VISIBLE_DEVICES"] = "3"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"PyTorch version: {torch.__version__}")
print(f"Using device: {DEVICE}")
if DEVICE == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.1.2
# Using device: cuda
# GPU: NVIDIA GeForce RTX 3080

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================

DATASET_NAME = "Srinivasavaradhan"

# "train_and_cpl" | "train_only" | "cpl_only"
RUN_MODE = "cpl_only"

# CPL: Multi-threshold sweep
CPL_PERCENTILES = [0, 5, 10, 15, 20, 25]

# ─── clustersizethreshold ───────────────────────────────────────────
# DNAformer paper (Supplementary §1.2, §7):
#   Illumina:  clustersizethreshold = 3  (confidencethreshold = 0)
#   Nanopore:  clustersizethreshold = 4  (confidencethreshold = 0.7)
# Derived by scanning small cluster sizes upward and finding where
# DNN success rate drops below 50%.
#
# Set None → auto-detect (DNAformer methodology). Set int → override.
CLUSTERSIZE_THRESHOLD_OVERRIDE = None

# =============================================================================
# DATASET CONFIGURATIONS
# =============================================================================

DATASET_CONFIGS = {
    "Erlich": {
        "label_len": 152, "index_length": 16, "max_deviation": 10,
        "filter_index": False, "target_failure": 0.02,
        "description": "Erlich et al. (2017) - DNA Fountain, Illumina miSeq",
    },
    "Grass": {
        "label_len": 117, "index_length": 13, "max_deviation": 11,
        "filter_index": False, "target_failure": 0.66,
        "description": "Grass et al. (2015) - CustomArray, Illumina miSeq",
    },
    "Organick": {
        "label_len": 110, "index_length": 33, "max_deviation": 5,
        "filter_index": False, "target_failure": 0.17,
        "description": "Organick et al. (2018) - Twist, Illumina NextSeq",
    },
    "Srinivasavaradhan": {
        "label_len": 110, "index_length": 4, "max_deviation": 10,
        "filter_index": False, "target_failure": 14.58,
        "description": "Srinivasavaradhan et al. - Twist, MinION",
    },
    "BinnedPilotIllumina": {
        "label_len": 128, "index_length": 12, "max_deviation": 4,
        "filter_index": True, "target_failure": 0.01,
        "description": "DNAformer Pilot Illumina",
    },
    "BinnedPilotNanopore": {
        "label_len": 128, "index_length": 12, "max_deviation": 10,
        "filter_index": True, "target_failure": 1.0,
        "description": "DNAformer Pilot Nanopore",
    },
    "BinnedTestIllumina": {
        "label_len": 128, "index_length": 12, "max_deviation": 4,
        "filter_index": True, "target_failure": 0.0055,
        "description": "DNAformer Test Illumina",
    },
    "BinnedNanoporeFirstFlowcell": {
        "label_len": 128, "index_length": 12, "max_deviation": 4,
        "filter_index": True, "target_failure": 3.88,
        "description": "DNAformer Nanopore Single Flowcell",
    },
    "BinnedNanoporeSecondFlowcell": {
        "label_len": 128, "index_length": 12, "max_deviation": 4,
        "filter_index": True, "target_failure": 4.5,
        "description": "DNAformer Nanopore Second Flowcell",
    },
    "BinnedNanoporeTwoFlowcells": {
        "label_len": 128, "index_length": 12, "max_deviation": 4,
        "filter_index": True, "target_failure": 1.65,
        "description": "DNAformer Nanopore Two Flowcells Combined",
    },
}

DATASET_FILES = {
    "Erlich": ("binned_synthetic_erlich.txt", "Erlich.txt"),
    "Grass": ("binned_synthetic_grass.txt", "Grass.txt"),
    "Organick": ("binned_synthetic_organick.txt", None),
    "Srinivasavaradhan": ("binned_synthetic_srinivasavaradhan.txt", "Srinivasavaradhan.txt"),
    "BinnedPilotIllumina": ("binned_synthetic_dnaformer_illumina_pilot.txt", "BinnedPilotIllumina.txt"),
    "BinnedPilotNanopore": ("binned_synthetic_dnaformer_nanopore_pilot.txt", "BinnedPilotNanopore.txt"),
    "BinnedTestIllumina": ("binned_synthetic_dnaformer_illumina_full.txt", "BinnedTestIllumina.txt"),
    "BinnedNanoporeFirstFlowcell": ("binned_synthetic_dnaformer_nanopore_full.txt", "BinnedNanoporeFirstFlowcell.txt"),
    "BinnedNanoporeSecondFlowcell": ("binned_synthetic_dnaformer_nanopore_full.txt", "BinnedNanoporeSecondFlowcell.txt"),
    "BinnedNanoporeTwoFlowcells": ("binned_synthetic_dnaformer_nanopore_full.txt", "BinnedNanoporeTwoFlowcells.txt"),
}

# =============================================================================
# DERIVED PARAMETERS
# =============================================================================

CONFIG = DATASET_CONFIGS[DATASET_NAME]
LABEL_SEQ_LEN = CONFIG["label_len"]
INDEX_LENGTH = CONFIG["index_length"]
MAX_DEVIATION = CONFIG["max_deviation"]
FILTER_INDEX = CONFIG["filter_index"]
MAX_CLUSTER_SIZE = 16

if FILTER_INDEX:
    ORIGINAL_SEQ_LEN = LABEL_SEQ_LEN + INDEX_LENGTH
else:
    ORIGINAL_SEQ_LEN = LABEL_SEQ_LEN

MAX_READ_LEN = ORIGINAL_SEQ_LEN + MAX_DEVIATION + 8

BATCH_SIZE = 200
LEARNING_RATE = 5e-4
MIN_LR = 5e-8
WEIGHT_DECAY = 1e-5
EPOCHS = 100
WARMUP_EPOCHS = 10
PATIENCE = 10

EMBED_DIM = 300
ALIGNMENT_FILTERS = 128
EMBEDDING_FILTERS = 500
GRU_HIDDEN = 300
GRU_LAYERS = 2
DROPOUT = 0.1

# =============================================================================
# PATHS
# =============================================================================

SYNTHETIC_DATA_DIR = Path("../generated_data_corrected")
REAL_DATA_DIR = Path("../Data")

_train_file, _eval_file = DATASET_FILES.get(DATASET_NAME, (None, None))
TRAIN_FILE = SYNTHETIC_DATA_DIR / _train_file if _train_file else None
EVAL_FILE = REAL_DATA_DIR / _eval_file if _eval_file else None

EXPERIMENT_DIR = Path(f"./Experiments/{DATASET_NAME}_v4")
WEIGHTS_DIR = EXPERIMENT_DIR / 'Models'
RESULTS_DIR = EXPERIMENT_DIR / 'Results'
FIGURES_DIR = EXPERIMENT_DIR / 'Figures'
MAT_DIR = EXPERIMENT_DIR / 'MatFiles'

if RUN_MODE == "cpl_only":
    MODEL_PATH = Path(f"./Experiments/{DATASET_NAME}_v4/Models/best_model_{DATASET_NAME}.pth")
    if not MODEL_PATH.exists():
        MODEL_PATH = WEIGHTS_DIR / f"best_model_{DATASET_NAME}.pth"
    if not MODEL_PATH.exists():
        raise FileNotFoundError(f"No model at {MODEL_PATH}")
    for d in [RESULTS_DIR, FIGURES_DIR, MAT_DIR]: d.mkdir(parents=True, exist_ok=True)
else:
    for d in [WEIGHTS_DIR, RESULTS_DIR, FIGURES_DIR, MAT_DIR]: d.mkdir(parents=True, exist_ok=True)
    MODEL_PATH = None

print(f"\n{'='*70}")
print(f"DATASET: {DATASET_NAME} | MODE: {RUN_MODE}")
print(f"{'='*70}")
print(f"  {CONFIG['description']}")
print(f"  LABEL_SEQ_LEN:   {LABEL_SEQ_LEN}")
print(f"  ORIGINAL_SEQ_LEN:{ORIGINAL_SEQ_LEN}")
print(f"  Target failure:  {CONFIG['target_failure']}%")
print(f"  CPL Percentiles: {CPL_PERCENTILES}")
print(f"  clustersizethreshold: {'auto-detect' if CLUSTERSIZE_THRESHOLD_OVERRIDE is None else CLUSTERSIZE_THRESHOLD_OVERRIDE}")
print(f"  Train: {TRAIN_FILE}")
print(f"  Eval:  {EVAL_FILE}")
print(f"{'='*70}\n")
# Out:
# ======================================================================
# DATASET: Srinivasavaradhan | MODE: cpl_only
# ======================================================================
#   Srinivasavaradhan et al. - Twist, MinION
#   LABEL_SEQ_LEN:   110
#   ORIGINAL_SEQ_LEN:110
#   Target failure:  14.58%
#   CPL Percentiles: [0, 5, 10, 15, 20, 25]
#   clustersizethreshold: auto-detect
#   Train: ../generated_data_corrected/binned_synthetic_srinivasavaradhan.txt
#   Eval:  ../Data/Srinivasavaradhan.txt
# ======================================================================

# %%
# =============================================================================
# VOCABULARY
# =============================================================================
 
VOCAB = {'N': 0, 'A': 1, 'C': 2, 'G': 3, 'T': 4}
PADDING_IDX = VOCAB['N']
VOCAB_SIZE = len(VOCAB)
INT_TO_CHAR = {i: c for c, i in VOCAB.items()}
DNA_BASES = ['A', 'C', 'G', 'T']
END_SYMBOL = 'S'
 
def encode_seq(seq, char_to_int, max_len, padding_idx):
    encoded = [char_to_int.get(c, padding_idx) for c in seq]
    encoded = encoded[:max_len]
    return encoded + [padding_idx] * (max_len - len(encoded))
 
def decode_seq(tensor, int_to_char):
    if tensor.is_cuda:
        tensor = tensor.cpu()
    ints = tensor.numpy().tolist()
    try:
        first_pad = ints.index(PADDING_IDX)
        ints = ints[:first_pad]
    except ValueError:
        pass
    return "".join([int_to_char.get(i, '?') for i in ints])

# %%
# =============================================================================
# DATASET
# =============================================================================
 
class DnaClusterDataset(Dataset):
    def __init__(self, filepath, max_cluster_size, max_read_len, label_seq_len,
                 char_to_int, padding_idx):
        self.max_cluster_size = max_cluster_size
        self.max_read_len = max_read_len
        self.label_seq_len = label_seq_len
        self.char_to_int = char_to_int
        self.padding_idx = padding_idx
        self.labels = []
        self.clusters = []
        self._load_data(filepath)
 
    def _load_data(self, filepath):
        print(f"Loading data from {filepath}...")
        with open(filepath, 'r') as f:
            content = f.read()
        blocks = content.split('\n\n')
        for block in tqdm(blocks, desc=f"Parsing {filepath.name}"):
            if not block.strip():
                continue
            lines = [l.strip() for l in block.strip().split('\n')]
            if len(lines) < 3:
                continue
            label_seq = lines[0]
            reads = [r for r in lines[2:] if r]
            if not reads or not label_seq:
                continue
            self.labels.append(label_seq)
            self.clusters.append(reads)
        print(f"Loaded {len(self.labels)} clusters.")
        # Verify label length
        if self.labels:
            actual = len(self.labels[0])
            print(f"  Label length in file: {actual}")
            if actual < self.label_seq_len:
                print(f"  ⚠️  WARNING: label in file ({actual}) < LABEL_SEQ_LEN ({self.label_seq_len})")
 
    def __len__(self):
        return len(self.labels)
 
    def __getitem__(self, idx):
        label_str = self.labels[idx]
        reads = list(self.clusters[idx])
        label_t = torch.tensor(
            encode_seq(label_str, self.char_to_int, self.label_seq_len, self.padding_idx),
            dtype=torch.long)
        cluster_t = torch.full((self.max_cluster_size, self.max_read_len),
                               self.padding_idx, dtype=torch.long)
        random.shuffle(reads)
        for i, r in enumerate(reads[:self.max_cluster_size]):
            cluster_t[i] = torch.tensor(
                encode_seq(r, self.char_to_int, self.max_read_len, self.padding_idx),
                dtype=torch.long)
        return cluster_t, label_t
 
    def get_raw_reads(self, idx): return self.clusters[idx]
    def get_raw_label(self, idx): return self.labels[idx]
    def get_cluster_size(self, idx): return len(self.clusters[idx])

# %%
# =============================================================================
# MODEL
# =============================================================================
 
class DepthwiseSeparableConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, padding=0):
        super().__init__()
        self.depthwise = nn.Conv1d(in_channels, in_channels, kernel_size=kernel_size,
                                   padding=padding, groups=in_channels)
        self.pointwise = nn.Conv1d(in_channels, out_channels, kernel_size=1)
    def forward(self, x): return self.pointwise(self.depthwise(x))
 
class MultiKernelConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, seq_len, dropout=0.1):
        super().__init__()
        c1 = out_channels // 3
        c2 = out_channels // 3
        c3 = out_channels - c1 - c2
        self.conv1 = DepthwiseSeparableConv1d(in_channels, c1, kernel_size=1)
        self.conv3 = DepthwiseSeparableConv1d(in_channels, c2, kernel_size=3, padding=1)
        self.conv5 = DepthwiseSeparableConv1d(in_channels, c3, kernel_size=5, padding=2)
        self.norm1 = nn.LayerNorm([c1, seq_len])
        self.norm2 = nn.LayerNorm([c2, seq_len])
        self.norm3 = nn.LayerNorm([c3, seq_len])
        self.dropout = nn.Dropout(dropout)
    def forward(self, x):
        x1 = F.gelu(self.norm1(self.conv1(x)))
        x2 = F.gelu(self.norm2(self.conv3(x)))
        x3 = F.gelu(self.norm3(self.conv5(x)))
        return self.dropout(torch.cat([x1, x2, x3], dim=1))

class AlignmentModule(nn.Module):
    def __init__(self, embed_dim, out_channels, seq_len, dropout=0.1):
        super().__init__()
        self.conv_block1 = MultiKernelConvBlock(embed_dim, out_channels, seq_len, dropout)
        self.conv_block2 = MultiKernelConvBlock(out_channels, out_channels, seq_len, dropout)
    def forward(self, x):
        batch, cluster, emb, seq = x.shape
        x = x.view(batch * cluster, emb, seq)
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        return x.view(batch, cluster, -1, seq)

class EmbeddingModule(nn.Module):
    def __init__(self, in_channels, out_channels, in_len, out_len, dropout=0.1):
        super().__init__()
        self.conv_block = MultiKernelConvBlock(in_channels, out_channels, in_len, dropout)
        self.linear = nn.Linear(in_len, out_len)
    def forward(self, x):
        x = self.conv_block(x)
        batch, channels, seq_len = x.shape
        x = x.reshape(batch * channels, seq_len)
        x = self.linear(x)
        return x.reshape(batch, channels, -1)

class ImprovedDNAReconstructionModel(nn.Module):
    def __init__(self, vocab_size, label_seq_len, max_read_len, padding_idx,
                 embed_dim=128, alignment_filters=128, embedding_filters=256,
                 gru_hidden=256, gru_layers=2, dropout=0.2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=padding_idx)
        self.alignment = AlignmentModule(embed_dim, alignment_filters, max_read_len, dropout)
        self.embedding_module = EmbeddingModule(
            alignment_filters, embedding_filters, max_read_len, label_seq_len, dropout)
        self.gru = nn.GRU(embedding_filters, gru_hidden, num_layers=gru_layers,
                          batch_first=True, bidirectional=True,
                          dropout=dropout if gru_layers > 1 else 0)
        self.dropout = nn.Dropout(dropout)
        self.fc_out = nn.Linear(gru_hidden * 2, vocab_size)
 
    def forward(self, cluster_batch, return_probs=False):
        emb = self.embedding(cluster_batch).permute(0, 1, 3, 2)
        aligned = self.alignment(emb)
        nci = torch.sum(aligned, dim=1)
        feats = self.embedding_module(nci).permute(0, 2, 1)
        gru_out, _ = self.gru(feats)
        logits = self.fc_out(self.dropout(gru_out))
        if return_probs:
            return logits, F.softmax(logits, dim=2)
        return logits

# %%
# =============================================================================
# SCHEDULER
# =============================================================================
 
class CosineAnnealingWarmupScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, max_lr, min_lr):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.current_epoch = 0
    def step(self):
        if self.current_epoch < self.warmup_epochs:
            lr = self.max_lr * (self.current_epoch + 1) / self.warmup_epochs
        else:
            progress = (self.current_epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.min_lr + (self.max_lr - self.min_lr) * 0.5 * (1 + math.cos(math.pi * progress))
        for pg in self.optimizer.param_groups:
            pg['lr'] = lr
        self.current_epoch += 1
        return lr
    def get_last_lr(self):
        return [pg['lr'] for pg in self.optimizer.param_groups]

# %%
# =============================================================================
# TRAINING UTILITIES
# =============================================================================
 
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    loop = tqdm(loader, desc="Training", leave=False)
    for clusters, labels in loop:
        clusters, labels = clusters.to(device), labels.to(device)
        logits = model(clusters)
        loss = criterion(logits.view(-1, VOCAB_SIZE), labels.view(-1))
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item()
        loop.set_postfix(loss=loss.item())
    return total_loss / len(loader)
 
def validate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    loop = tqdm(loader, desc="Validating", leave=False)
    with torch.no_grad():
        for clusters, labels in loop:
            clusters, labels = clusters.to(device), labels.to(device)
            logits = model(clusters)
            loss = criterion(logits.view(-1, VOCAB_SIZE), labels.view(-1))
            total_loss += loss.item()
            loop.set_postfix(loss=loss.item())
    return total_loss / len(loader)

# %%
# =============================================================================
# CPL ALGORITHM — Python translation of DNAformer C++
# =============================================================================
 
NINF = float('-inf')
NA = -1
 
def edit_distance_dp(X, Y):
    m, n = len(X), len(Y)
    dp = [[0]*(n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j
    for i in range(1, m+1):
        for j in range(1, n+1):
            if X[i-1] == Y[j-1]: dp[i][j] = dp[i-1][j-1]
            else: dp[i][j] = 1 + min(dp[i-1][j-1], dp[i-1][j], dp[i][j-1])
    return dp[m][n], dp
 
def edit_distance(X, Y): return edit_distance_dp(X, Y)[0]
def sum_ed(s, strs): return sum(edit_distance(s, t) for t in strs)
 
def backtrack_edit_vector(X, Y, dp):
    m, n = len(X), len(Y)
    ev = [""]*(2*m+1)
    mi, ni = m, n
    while True:
        if mi == 0: ev[0] = Y[:ni]; break
        elif ni == 0:
            for idx in range(mi): ev[2*idx+1] = ""
            break
        if X[mi-1] == Y[ni-1]: ev[2*mi-1] = X[mi-1]; mi -= 1; ni -= 1
        else:
            codes = []
            if dp[mi][ni] == dp[mi-1][ni-1]+1: codes.append(0)
            if dp[mi][ni] == dp[mi][ni-1]+1: codes.append(1)
            if dp[mi][ni] == dp[mi-1][ni]+1: codes.append(2)
            if len(codes) > 1: random.shuffle(codes)
            c = codes[0]
            if c == 0: ev[2*mi-1] = Y[ni-1]; mi -= 1; ni -= 1
            elif c == 1: ev[2*mi] = Y[ni-1] + ev[2*mi]; ni -= 1
            else: ev[2*mi-1] = ""; mi -= 1
    return ev
 
def edit_vector(X, Y):
    _, dp = edit_distance_dp(X, Y)
    return backtrack_edit_vector(X, Y, dp)
 
def anchor_w_all_pairs_ev(anchor_index, reads):
    anchor = reads[anchor_index]
    return [edit_vector(anchor, reads[i]) for i in range(len(reads)) if i != anchor_index]
 
def add_conditional_freq(ev, cfv):
    for i in range(len(ev)-1):
        fs, ts = ev[i], ev[i+1]
        if fs not in cfv[i]: cfv[i][fs] = ({}, 0)
        tc, tot = cfv[i][fs]; tc[ts] = tc.get(ts, 0)+1; cfv[i][fs] = (tc, tot+1)
    last = len(ev)-1; fs = ev[last]
    if fs not in cfv[last]: cfv[last][fs] = ({}, 0)
    tc, tot = cfv[last][fs]; tc[END_SYMBOL] = tc.get(END_SYMBOL, 0)+1; cfv[last][fs] = (tc, tot+1)

def conditional_freq_vec(all_ev):
    cf = [{} for _ in range(len(all_ev[0]))]
    for ev in all_ev: add_conditional_freq(ev, cf)
    return cf
 
def freq_to_prob_log(fv):
    pv = [{} for _ in range(len(fv))]
    tf = sum(v[1] for v in fv[0].values())
    for fs, (tc, fc) in fv[0].items():
        pv[0][fs] = {ts: math.log(c/tf) for ts, c in tc.items()}
    for i in range(1, len(fv)):
        for fs, (tc, fc) in fv[i].items():
            pv[i][fs] = {ts: math.log(c/fc) for ts, c in tc.items()}
    return pv
 
def prob_vec(anchor_index, reads):
    aev = anchor_w_all_pairs_ev(anchor_index, reads)
    if not aev: return None
    return freq_to_prob_log(conditional_freq_vec(aev))
 
def count_letters(prob): return sum(len(s) for lv in prob for s in lv)
 
def cond_prob_to_graph(prob):
    V = count_letters(prob)+2; letters = ['']*V; adj = [[] for _ in range(V)]
    llv = {}; cv = []; vi = V-1
    letters[vi] = END_SYMBOL; llv[END_SYMBOL] = vi; vi -= 1
    for level in reversed(prob):
        he = False; clv = {}
        for cs, cm in level.items():
            sl = len(cs)
            if sl == 0: he = True; continue
            elif sl == 1:
                letters[vi] = cs[0]
                for ts, wt in cm.items():
                    if len(ts) == 0:
                        for c, w in cv: adj[vi].append((c, w+wt))
                    elif ts in llv: adj[vi].append((llv[ts], wt))
                clv[cs] = vi; vi -= 1
            else:
                letters[vi] = cs[-1]
                for ts, wt in cm.items():
                    if len(ts) == 0:
                        for c, w in cv: adj[vi].append((c, w+wt))
                    elif ts in llv: adj[vi].append((llv[ts], wt))
                vi -= 1
                for si in range(sl-2, -1, -1):
                    letters[vi] = cs[si]; adj[vi].append((vi+1, 0.0)); vi -= 1
                clv[cs] = vi+1
        if he and "" in level:
            em = level[""]
            if "" not in em: cv = []
            else: ew = em[""]; cv = [(c, w+ew) for c, w in cv]
            for ts, wt in em.items():
                if ts == "": continue
                if ts in llv: cv.append((llv[ts], wt))
        else: cv = []
        llv = clv
    assert vi == 0; letters[0] = END_SYMBOL
    for s, v in llv.items(): adj[0].append((v, 0.0))
    for c, w in cv: adj[0].append((c, w))
    return letters, adj, V
 
def count_strings(prob): return sum(len(lv) for lv in prob)
 
def cond_prob_to_strings_graph(prob):
    V = count_strings(prob)+2; vts = [""]*V; adj = [[] for _ in range(V)]
    vts[0] = END_SYMBOL; vts[V-1] = END_SYMBOL
    s2v = [{} for _ in range(len(prob))]; vx = 1
    for li in range(len(prob)):
        for fs in prob[li]: vts[vx] = fs; s2v[li][fs] = vx; vx += 1
    for fs in prob[0]: adj[0].append((s2v[0][fs], 0.0))
    for li in range(len(prob)-1):
        for fs, tm in prob[li].items():
            fv = s2v[li][fs]
            for ts, wt in tm.items(): adj[fv].append((s2v[li+1][ts], wt))
    last = len(prob)-1
    for fs, tm in prob[last].items():
        fv = s2v[last][fs]
        for ts, wt in tm.items(): adj[fv].append((V-1, wt))
    return vts, adj, V
 
def min_max_letters_to_end(letters, adj, V):
    ev = V-1; ra = [[] for _ in range(V)]
    for u in range(V):
        for v, w in adj[u]: ra[v].append((u, 1))
    vis = [False]*V; to = []
    def dfs(v):
        stk = [(v, False)]
        while stk:
            nd, dn = stk.pop()
            if dn: to.append(nd); continue
            if vis[nd]: continue
            vis[nd] = True; stk.append((nd, True))
            for nb, w in ra[nd]:
                if not vis[nb]: stk.append((nb, False))
    for i in range(V):
        if not vis[i]: dfs(i)
    mnd = [float('inf')]*V; mnd[ev] = 0
    mxd = [float('-inf')]*V; mxd[ev] = 0
    for u in reversed(to):
        if mnd[u] != float('inf'):
            for nb, w in ra[u]:
                if mnd[nb] > mnd[u]+w: mnd[nb] = mnd[u]+w
        if mxd[u] != float('-inf'):
            for nb, w in ra[u]:
                if mxd[nb] < mxd[u]+w: mxd[nb] = mxd[u]+w
    mnl = [0]*V; mxl = [0]*V
    for v in range(V-1):
        mnl[v] = mnd[v]-1 if mnd[v] != float('inf') else 0
        mxl[v] = mxd[v]-1 if mxd[v] != float('-inf') else 0
    return mnl, mxl
 
def highest_score_fixed_len_path(letters, adj, mnl, mxl, tl):
    V = len(letters); ev = V-1; K = tl+1
    dp = [dict() for _ in range(K+1)]; dp[0][0] = (0.0, NA)
    for i in range(K):
        if not dp[i]: return ""
        for fv, (fval, _) in dp[i].items():
            for tv, wt in adj[fv]:
                lsf = i+1
                if tv != ev:
                    if lsf+mnl[tv] > tl: continue
                    if lsf+mxl[tv] < tl: continue
                nw = fval+wt
                if tv not in dp[i+1] or dp[i+1][tv][0] < nw: dp[i+1][tv] = (nw, fv)
    if ev not in dp[K]: return ""
    r = []; nv = ev
    for j in range(K, 1, -1): p = dp[j][nv][1]; r.append(letters[p]); nv = p
    r.reverse(); return "".join(r)
 
def longest_path_dag(adj, V, src, tgt):
    vis = [False]*V; to = []
    def dfs(v):
        stk = [(v, False)]
        while stk:
            nd, dn = stk.pop()
            if dn: to.append(nd); continue
            if vis[nd]: continue
            vis[nd] = True; stk.append((nd, True))
            for nb, w in adj[nd]:
                if not vis[nb]: stk.append((nb, False))
    for i in range(V):
        if not vis[i]: dfs(i)
    dist = [NINF]*V; par = [NA]*V; dist[src] = 0.0
    for u in reversed(to):
        if dist[u] == NINF: continue
        for nb, w in adj[u]:
            if dist[nb] < dist[u]+w: dist[nb] = dist[u]+w; par[nb] = u
    if dist[tgt] == NINF: return []
    path = []; c = tgt
    while c != NA: path.append(c); c = par[c] if c != src else NA
    if not path or path[-1] != src: path.append(src)
    path.reverse(); return path
 
def heaviest_path_string(vts, adj, V):
    path = longest_path_dag(adj, V, 0, V-1)
    if not path: return ""
    return "".join(vts[v] for v in path[1:-1])
 
def fixed_len_markov(reads, ai, tl):
    prob = prob_vec(ai, reads)
    if prob is None: return ""
    try:
        l, a, V = cond_prob_to_graph(prob)
        mn, mx = min_max_letters_to_end(l, a, V)
        return highest_score_fixed_len_path(l, a, mn, mx, tl)
    except: return ""

def heaviest_path(reads, ai):
    prob = prob_vec(ai, reads)
    if prob is None: return ""
    try:
        vts, a, V = cond_prob_to_strings_graph(prob)
        return heaviest_path_string(vts, a, V)
    except: return ""

def correct_cluster(reads, tl):
    corrected = []
    for i in range(len(reads)):
        g = fixed_len_markov(reads, i, tl)
        if not g: g = heaviest_path(reads, i)
        corrected.append(g)
    return corrected
 
def correct_cluster_twice(reads, tl):
    return correct_cluster(correct_cluster(reads, tl), tl)
 
def min_sum_ed_index(cands, orig):
    bi, bs = 0, float('inf')
    for i, c in enumerate(cands):
        s = sum_ed(c, orig)
        if s < bs: bs = s; bi = i
    return bi
 
def min_sum_ed_corrected_cluster_twice(reads, tl):
    if len(reads) == 1: return reads[0]
    corr = correct_cluster_twice(reads, tl)
    uniq = list(set(corr))
    if not uniq: return reads[0]
    return uniq[min_sum_ed_index(uniq, reads)]
 
def run_cpl_on_cluster(reads, original_length, output_length=None):
    """CPL: reconstruct full strand (original_length), output first output_length bases."""
    if output_length is None: output_length = original_length
    cleaned = [r.strip() for r in reads]
    valid = [r for r in cleaned if len(r) > 0 and set(r).issubset({'A','C','G','T'})]
    if len(valid) < 2:
        if valid: return valid[0][:output_length]
        return ''.join(random.choices(DNA_BASES, k=output_length))
    if len(valid) > MAX_CLUSTER_SIZE: valid = valid[:MAX_CLUSTER_SIZE]
    result = min_sum_ed_corrected_cluster_twice(valid, original_length)
    return result[:output_length]

# %%
# =============================================================================
# CONFIDENCE FILTER
# =============================================================================
 
class ConfidenceFilter:
    def __init__(self, threshold, min_cluster_for_cpl=4):
        self.threshold = threshold
        self.min_cluster = min_cluster_for_cpl
    def classify(self, probs, cluster_size):
        dna_probs = probs[:, 1:]
        m_M = dna_probs.max(dim=1).values.mean().item()
        if m_M >= self.threshold: return 'trust_dnn', m_M
        elif cluster_size <= self.min_cluster: return 'erasure', m_M
        else: return 'send_to_cpl', m_M

# %%
# =============================================================================
# TRAINING (skip if cpl_only)
# =============================================================================
 
if RUN_MODE in ("train_and_cpl", "train_only"):
    assert TRAIN_FILE and TRAIN_FILE.exists(), f"Training file not found: {TRAIN_FILE}"
 
    print(f"\n{'='*70}\nLOADING TRAINING DATA\n{'='*70}\n")
 
    full_train_dataset = DnaClusterDataset(
        TRAIN_FILE, MAX_CLUSTER_SIZE, MAX_READ_LEN,
        LABEL_SEQ_LEN, VOCAB, PADDING_IDX)
 
    val_size = int(0.02 * len(full_train_dataset))
    if val_size < BATCH_SIZE:
        val_size = min(BATCH_SIZE * 2, len(full_train_dataset) // 10)
    train_size = len(full_train_dataset) - val_size
    train_dataset, val_dataset = random_split(full_train_dataset, [train_size, val_size])
    print(f"Total: {len(full_train_dataset):,} | Train: {train_size:,} | Val: {val_size:,}")
 
    train_loader = DataLoader(train_dataset, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
 
    model = ImprovedDNAReconstructionModel(
        VOCAB_SIZE, LABEL_SEQ_LEN, MAX_READ_LEN, PADDING_IDX,
        EMBED_DIM, ALIGNMENT_FILTERS, EMBEDDING_FILTERS,
        GRU_HIDDEN, GRU_LAYERS, DROPOUT).to(DEVICE)
    print(f"Model: {sum(p.numel() for p in model.parameters()):,} params")
 
    criterion = nn.CrossEntropyLoss(ignore_index=PADDING_IDX, label_smoothing=0.1)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    scheduler = CosineAnnealingWarmupScheduler(optimizer, WARMUP_EPOCHS, EPOCHS, LEARNING_RATE, MIN_LR)
 
    print(f"\n{'='*70}\nTRAINING: {DATASET_NAME}\n{'='*70}\n")
    best_val_loss = float('inf')
    patience_counter = 0
    train_losses, val_losses, learning_rates = [], [], []
 
    for epoch in range(EPOCHS):
        t0 = time.time()
        current_lr = scheduler.get_last_lr()[0]
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
        val_loss = validate(model, val_loader, criterion, DEVICE)
        scheduler.step()
        train_losses.append(train_loss); val_losses.append(val_loss); learning_rates.append(current_lr)
        print(f"Epoch {epoch+1:3d}/{EPOCHS} | LR: {current_lr:.2e} | "
              f"Train: {train_loss:.4f} | Val: {val_loss:.4f} | "
              f"Time: {time.time()-t0:.1f}s", end="")
        if val_loss < best_val_loss:
            imp = best_val_loss - val_loss; best_val_loss = val_loss
            torch.save(model.state_dict(), WEIGHTS_DIR / f"best_model_{DATASET_NAME}.pth")
            print(f" ✓ BEST (↓{imp:.4f})"); patience_counter = 0
        else: print(); patience_counter += 1
        if patience_counter >= PATIENCE: print(f"\nEarly stopping at epoch {epoch+1}"); break
 
    torch.save(model.state_dict(), WEIGHTS_DIR / f"final_model_{DATASET_NAME}.pth")
    MODEL_PATH = WEIGHTS_DIR / f"best_model_{DATASET_NAME}.pth"
    pd.DataFrame({'epoch': range(1, len(train_losses)+1), 'train_loss': train_losses,
                  'val_loss': val_losses, 'learning_rate': learning_rates
                  }).to_csv(RESULTS_DIR / f"history_{DATASET_NAME}.csv", index=False)
    print(f"\nBest val loss: {best_val_loss:.4f} | Models: {WEIGHTS_DIR}")
    if RUN_MODE == "train_only":
        print(f"\n{'='*70}\nTRAINING COMPLETE (train_only)\n{'='*70}")
else:
    print(f"Skipping training (RUN_MODE='{RUN_MODE}')")
# Out:
# Skipping training (RUN_MODE='cpl_only')

# %%
# =============================================================================
# LOAD MODEL + TEST DATA
# =============================================================================
 
if RUN_MODE != "train_only":
    assert EVAL_FILE and EVAL_FILE.exists(), f"Eval not found: {EVAL_FILE}"
    assert MODEL_PATH and os.path.isfile(str(MODEL_PATH)), f"Model not found: {MODEL_PATH}"
 
    print(f"\n{'='*70}\nLOADING MODEL\n{'='*70}")
    model = ImprovedDNAReconstructionModel(
        VOCAB_SIZE, LABEL_SEQ_LEN, MAX_READ_LEN, PADDING_IDX,
        EMBED_DIM, ALIGNMENT_FILTERS, EMBEDDING_FILTERS,
        GRU_HIDDEN, GRU_LAYERS, DROPOUT).to(DEVICE)
    model.load_state_dict(torch.load(str(MODEL_PATH), map_location=DEVICE, weights_only=True))
    model.eval()
    print(f"✓ Loaded ({sum(p.numel() for p in model.parameters()):,} params) from {MODEL_PATH}")
 
    test_ds = DnaClusterDataset(EVAL_FILE, MAX_CLUSTER_SIZE, MAX_READ_LEN,
                                LABEL_SEQ_LEN, VOCAB, PADDING_IDX)
    test_loader = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
# Out:
# ======================================================================
# LOADING MODEL
# ======================================================================
# ✓ Loaded (3,405,643 params) from Experiments/Srinivasavaradhan_v4/Models/best_model_Srinivasavaradhan.pth
# Loading data from ../Data/Srinivasavaradhan.txt...
# /homes/shubham/anaconda3/envs/pytorchenv/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110

# %%
# =============================================================================
# STAGE 0: MULTI-RUN VARIANCE ANALYSIS (DNN-only)
# =============================================================================
# DnaClusterDataset shuffles read order within each cluster at load time.
# This causes slight variation in DNN predictions across runs.
# We quantify this variance here, then proceed with the main single-run pipeline.
#
# Note: This cell is independent — it does NOT set variables used by later cells.

N_RUNS = 10  # Number of evaluation runs for variance estimation

if RUN_MODE != "train_only":
    _var_model_path = MODEL_PATH
    if _var_model_path is None:
        _var_model_path = WEIGHTS_DIR / f'best_model_{DATASET_NAME}.pth'
    assert _var_model_path and os.path.isfile(str(_var_model_path)), f'Model not found: {_var_model_path}'

    print(f"\n{'='*70}")
    print(f"STAGE 0: Multi-Run Variance Analysis ({N_RUNS} runs)")
    print(f"{'='*70}\n")

    _var_model = ImprovedDNAReconstructionModel(
        VOCAB_SIZE, LABEL_SEQ_LEN, MAX_READ_LEN, PADDING_IDX,
        EMBED_DIM, ALIGNMENT_FILTERS, EMBEDDING_FILTERS,
        GRU_HIDDEN, GRU_LAYERS, DROPOUT).to(DEVICE)
    _var_model.load_state_dict(torch.load(str(_var_model_path), map_location=DEVICE, weights_only=True))
    _var_model.eval()

    run_failures = []
    run_failure_indices = []

    for run in range(N_RUNS):
        random.seed(run)
        np.random.seed(run)

        _var_ds = DnaClusterDataset(EVAL_FILE, MAX_CLUSTER_SIZE, MAX_READ_LEN,
                                     LABEL_SEQ_LEN, VOCAB, PADDING_IDX)
        _var_loader = DataLoader(_var_ds, BATCH_SIZE, shuffle=False,
                                 num_workers=0, pin_memory=True)

        _preds, _labels = [], []
        with torch.no_grad():
            for clusters, labels in _var_loader:
                logits = _var_model(clusters.to(DEVICE))
                preds = logits.argmax(dim=2).cpu()
                for i in range(labels.shape[0]):
                    _preds.append(preds[i])
                    _labels.append(labels[i])

        N_var = len(_preds)
        failed_idx = [i for i in range(N_var)
                      if decode_seq(_preds[i], INT_TO_CHAR) != decode_seq(_labels[i], INT_TO_CHAR)]
        run_failures.append(len(failed_idx))
        run_failure_indices.append(set(failed_idx))
        print(f'  Run {run+1:>2}/{N_RUNS}: {len(failed_idx):>4} failures ({len(failed_idx)/N_var*100:.4f}%)')

    failures_arr = np.array(run_failures)
    rates_arr = failures_arr / N_var * 100

    # Identify stable vs flipping clusters
    all_ever_failed = set()
    for s in run_failure_indices:
        all_ever_failed |= s
    always_failed = set.intersection(*run_failure_indices) if run_failure_indices else set()
    sometimes_failed = all_ever_failed - always_failed

    print(f'\n  Summary over {N_RUNS} runs (N={N_var:,}):')
    print(f'    Failures:  {failures_arr.mean():.1f} ± {failures_arr.std():.1f}')
    print(f'    Rate:      {rates_arr.mean():.4f}% ± {rates_arr.std():.4f}%')
    print(f'    Range:     [{failures_arr.min()}, {failures_arr.max()}]')
    print(f'\n    Always fail (every run):     {len(always_failed)}')
    print(f'    Sometimes fail (flipping):   {len(sometimes_failed)}')
    print(f'    Total unique failures seen:  {len(all_ever_failed)}')

    # Save results
    pd.DataFrame({
        'run': range(1, N_RUNS+1),
        'failures': run_failures,
        'rate_pct': rates_arr.tolist(),
    }).to_csv(RESULTS_DIR / f'multirun_variance_{DATASET_NAME}.csv', index=False)

    sio.savemat(str(MAT_DIR / f'multirun_variance_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'n_runs': np.float64(N_RUNS),
        'N': np.float64(N_var),
        'failures_per_run': failures_arr.astype(np.float64),
        'rates_per_run': rates_arr,
        'mean_failures': np.float64(failures_arr.mean()),
        'std_failures': np.float64(failures_arr.std()),
        'mean_rate_pct': np.float64(rates_arr.mean()),
        'std_rate_pct': np.float64(rates_arr.std()),
        'always_fail_count': np.float64(len(always_failed)),
        'sometimes_fail_count': np.float64(len(sometimes_failed)),
    })
    print(f'\n  → Saved to {RESULTS_DIR} and {MAT_DIR}')

    # Reset random state so subsequent cells are not affected
    random.seed()
    np.random.seed()

    # Clean up memory
    del _var_model, _var_ds, _var_loader, _preds, _labels
    if DEVICE == 'cuda': torch.cuda.empty_cache()

    print(f'\n  For paper: "{rates_arr.mean():.4f}% ± {rates_arr.std():.4f}% (mean ± std, n={N_RUNS})"')
# Out:
# ======================================================================
# STAGE 0: Multi-Run Variance Analysis (10 runs)
# ======================================================================
#
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  1/10: 1437 failures (14.4364%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  2/10: 1447 failures (14.5369%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  3/10: 1462 failures (14.6876%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  4/10: 1446 failures (14.5268%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  5/10: 1453 failures (14.5971%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  6/10: 1448 failures (14.5469%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  7/10: 1447 failures (14.5369%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  8/10: 1446 failures (14.5268%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run  9/10: 1447 failures (14.5369%)
# Loading data from ../Data/Srinivasavaradhan.txt...
# Parsing Srinivasavaradhan.txt:   0%|          | 0/9955 [00:00<?, ?it/s]
# Loaded 9954 clusters.
#   Label length in file: 110
#   Run 10/10: 1450 failures (14.5670%)
#
#   Summary over 10 runs (N=9,954):
#     Failures:  1448.3 ± 6.0
#     Rate:      14.5499% ± 0.0599%
#     Range:     [1437, 1462]
#
#     Always fail (every run):     1334
#     Sometimes fail (flipping):   384
#     Total unique failures seen:  1718
#
#   → Saved to Experiments/Srinivasavaradhan_v4/Results and Experiments/Srinivasavaradhan_v4/MatFiles
#
#   For paper: "14.5499% ± 0.0599% (mean ± std, n=10)"

# %%
# =============================================================================
# STAGE 1: DNN INFERENCE
# =============================================================================
 
if RUN_MODE != "train_only":
    print(f"\n{'='*70}\nSTAGE 1: DNN Inference\n{'='*70}\n")
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for clusters, labels in tqdm(test_loader, desc="DNN"):
            logits, probs = model(clusters.to(DEVICE), return_probs=True)
            preds = logits.argmax(dim=2).cpu(); probs_cpu = probs.cpu()
            for i in range(labels.shape[0]):
                all_preds.append(preds[i]); all_probs.append(probs_cpu[i]); all_labels.append(labels[i])
    N = len(all_preds)
    dnn_failed = sum(1 for i in range(N)
        if decode_seq(all_preds[i], INT_TO_CHAR) != decode_seq(all_labels[i], INT_TO_CHAR))
    dnn_rate = dnn_failed / N * 100
    print(f"  Total: {N:,}\n  DNN-only failures: {dnn_failed:,} ({dnn_rate:.4f}%)")
# Out:
# ======================================================================
# STAGE 1: DNN Inference
# ======================================================================
# DNN:   0%|          | 0/50 [00:00<?, ?it/s]
#   Total: 9,954
#   DNN-only failures: 1,456 (14.6273%)

# %%
# =============================================================================
# PRE-COMPUTE (after DNN inference, before confidence analysis)
# =============================================================================

if RUN_MODE != "train_only":
    dnn_decoded = [decode_seq(all_preds[i], INT_TO_CHAR) for i in range(N)]
    label_decoded = [decode_seq(all_labels[i], INT_TO_CHAR) for i in range(N)]
    dnn_correct_mask = np.array([dnn_decoded[i] == label_decoded[i] for i in range(N)])
    dnn_fail_mask = ~dnn_correct_mask
    cluster_sizes = np.array([test_ds.get_cluster_size(i) for i in range(N)])

# %%
# =============================================================================
# STAGE 2a: Auto-detect clustersizethreshold
# =============================================================================
# DNAformer methodology (Supplementary §1.2, §7):
#   Scan cluster sizes from SMALL to LARGE.
#   Find the largest small cluster size where DNN success rate < 50%.
#   Illumina → 3, Nanopore → 4.
#
# Key: only consider small sizes with enough samples (≥20 clusters).
# A single failed cluster at size 630 should NOT set the threshold to 630.

if RUN_MODE != "train_only":
    print(f"\n{'='*70}")
    print(f"STAGE 2a: Cluster Size Analysis (auto-detect clustersizethreshold)")
    print(f"{'='*70}\n")

    MIN_SAMPLES_FOR_THRESHOLD = 20  # Need enough samples for reliable estimate

    size_correct = defaultdict(int)
    size_total = defaultdict(int)
    for i in range(N):
        cs = cluster_sizes[i]
        size_total[cs] += 1
        if dnn_correct_mask[i]:
            size_correct[cs] += 1

    all_sizes_sorted = sorted(size_total.keys())
    size_success_rate = {}
    print(f"  {'Size':>6} {'Total':>8} {'Correct':>8} {'Failed':>8} {'Rate':>10}")
    print(f"  {'-'*6} {'-'*8} {'-'*8} {'-'*8} {'-'*10}")
    for cs in all_sizes_sorted:
        tot = size_total[cs]
        cor = size_correct[cs]
        rate = cor / tot * 100 if tot > 0 else 0
        size_success_rate[cs] = rate
        marker = " ← <50%" if rate < 50 and tot >= MIN_SAMPLES_FOR_THRESHOLD else ""
        print(f"  {cs:>6} {tot:>8,} {cor:>8,} {tot-cor:>8,} {rate:>9.1f}%{marker}")

    if CLUSTERSIZE_THRESHOLD_OVERRIDE is not None:
        CLUSTERSIZE_THRESHOLD = CLUSTERSIZE_THRESHOLD_OVERRIDE
        print(f"\n  clustersizethreshold = {CLUSTERSIZE_THRESHOLD} (user override)")
    else:
        # DNAformer method: scan from smallest upward, stop when success >= 50%
        # Only consider sizes with enough samples
        CLUSTERSIZE_THRESHOLD = 0  # default: no erasures
        for cs in all_sizes_sorted:
            if size_total[cs] >= MIN_SAMPLES_FOR_THRESHOLD and size_success_rate[cs] < 50.0:
                CLUSTERSIZE_THRESHOLD = cs
            elif size_total[cs] >= MIN_SAMPLES_FOR_THRESHOLD and size_success_rate[cs] >= 50.0:
                break  # Stop at first reliable size with good performance
        print(f"\n  Auto-detected clustersizethreshold = {CLUSTERSIZE_THRESHOLD}")
        if CLUSTERSIZE_THRESHOLD == 0:
            print(f"  (No small cluster size has <50% success → DNN works well at all sizes)")

    # Save
    cs_df = pd.DataFrame([{
        'cluster_size': cs, 'total': size_total[cs], 'correct': size_correct[cs],
        'failed': size_total[cs] - size_correct[cs], 'success_rate_pct': size_success_rate[cs]
    } for cs in all_sizes_sorted])
    cs_df.to_csv(RESULTS_DIR / f'cluster_size_analysis_{DATASET_NAME}.csv', index=False)

    sio.savemat(str(MAT_DIR / f'figS1_clustersize_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'cluster_sizes': np.array(all_sizes_sorted, dtype=np.float64),
        'success_rates': np.array([size_success_rate[cs] for cs in all_sizes_sorted], dtype=np.float64),
        'cluster_counts': np.array([size_total[cs] for cs in all_sizes_sorted], dtype=np.float64),
        'clustersize_threshold': np.float64(CLUSTERSIZE_THRESHOLD),
    })
    print(f"  → Saved CSV + .mat")
# Out:
# ======================================================================
# STAGE 2a: Cluster Size Analysis (auto-detect clustersizethreshold)
# ======================================================================
#
#     Size    Total  Correct   Failed       Rate
#   ------ -------- -------- -------- ----------
#        1       85        1       84       1.2% ← <50%
#        2      151        5      146       3.3% ← <50%
#        3      214       54      160      25.2% ← <50%
#        4      308      145      163      47.1% ← <50%
#        5      391      238      153      60.9%
#        6      470      343      127      73.0%
#        7      498      410       88      82.3%
#        8      501      420       81      83.8%
#        9      546      475       71      87.0%
#       10      536      484       52      90.3%
#       11      524      488       36      93.1%
#       12      471      431       40      91.5%
#       13      462      430       32      93.1%
#       14      397      378       19      95.2%
#       15      373      351       22      94.1%
#       16      314      306        8      97.5%
#       17      323      306       17      94.7%
#       18      252      238       14      94.4%
#       19      234      217       17      92.7%
#       20      219      212        7      96.8%
#       21      226      222        4      98.2%
#       22      166      160        6      96.4%
#       23      162      155        7      95.7%
#       24      157      151        6      96.2%
#       25      138      132        6      95.7%
#       26      139      131        8      94.2%
#       27      106       98        8      92.5%
#       28      102       94        8      92.2%
#       29      118      109        9      92.4%
#       30      105       99        6      94.3%
#       31       97       92        5      94.8%
#       32       61       59        2      96.7%
#       33       82       77        5      93.9%
#       34       81       78        3      96.3%
#       35       74       72        2      97.3%
#       36       61       57        4      93.4%
#       37       68       62        6      91.2%
#       38       53       50        3      94.3%
#       39       54       50        4      92.6%
#       40       62       61        1      98.4%
#       41       46       44        2      95.7%
#       42       29       29        0     100.0%
#       43       47       45        2      95.7%
#       44       39       38        1      97.4%
#       45       37       35        2      94.6%
#       46       29       28        1      96.6%
#       47       27       27        0     100.0%
#       48       30       29        1      96.7%
#       49       34       31        3      91.2%
#       50       20       20        0     100.0%
#       51       18       18        0     100.0%
#       52       15       15        0     100.0%
#       53       19       19        0     100.0%
#       54       19       17        2      89.5%
#       55       15       15        0     100.0%
#       56       13       13        0     100.0%
#       57       11       10        1      90.9%
#       58       15       15        0     100.0%
#       59        8        8        0     100.0%
#       60       11       11        0     100.0%
#       61       11       11        0     100.0%
#       62        4        4        0     100.0%
#       63        6        6        0     100.0%
#       64        2        2        0     100.0%
#       65        7        7        0     100.0%
#       66        5        5        0     100.0%
#       67       11       11        0     100.0%
#       68        6        6        0     100.0%
#       69        5        5        0     100.0%
#       70        4        4        0     100.0%
#       71        4        4        0     100.0%
#       72        1        1        0     100.0%
#       73        3        3        0     100.0%
#       74        2        2        0     100.0%
#       75        2        1        1      50.0%
#       76        2        2        0     100.0%
#       77        2        2        0     100.0%
#       78        2        2        0     100.0%
#       80        1        1        0     100.0%
#       81        5        5        0     100.0%
#       82        1        1        0     100.0%
#       83        1        1        0     100.0%
#       86        1        1        0     100.0%
#       90        1        1        0     100.0%
#       96        1        1        0     100.0%
#      108        1        1        0     100.0%
#
#   Auto-detected clustersizethreshold = 4
#   → Saved CSV + .mat

# %%
# =============================================================================
# STAGE 2b: Confidence Analysis
# =============================================================================

if RUN_MODE != "train_only":
    print(f"\n{'='*70}")
    print(f"STAGE 2b: Confidence Analysis (clustersizethreshold={CLUSTERSIZE_THRESHOLD})")
    print(f"{'='*70}\n")

    m_scores = [all_probs[i][:, 1:].max(dim=1).values.mean().item() for i in range(N)]
    m_arr = np.array(m_scores)
    correct_scores = m_arr[dnn_correct_mask]
    fail_scores = m_arr[dnn_fail_mask] if dnn_failed > 0 else np.array([])

    print(f"  m(M): mean={m_arr.mean():.6f} median={np.median(m_arr):.6f} std={m_arr.std():.6f}")
    if dnn_failed > 0:
        print(f"  Correct: mean={correct_scores.mean():.6f}  Failed: mean={fail_scores.mean():.6f}")
        for idx, s in enumerate(fail_scores):
            pctile = np.searchsorted(np.sort(m_arr), s) / N * 100
            print(f"    Failure {idx+1}: m(M)={s:.6f}, percentile={pctile:.1f}%")
    else:
        print(f"  DNN has zero failures.")

    # Sweep preview
    print(f"\n  {'Pctl':>5} {'Thr':>10} {'Sent':>8} {'Era':>6} {'Capt':>6} {'AtRisk':>8} {'~Net':>6}")
    for pct in CPL_PERCENTILES:
        if pct == 0:
            print(f"  {'p0':>5} {'DNN-only':>10} {'0':>8} {'0':>6} {'0':>6} {'0':>8} {'0':>6}")
            continue
        thr = np.percentile(m_arr, pct)
        below = m_arr < thr
        can_cpl = below & (cluster_sizes > CLUSTERSIZE_THRESHOLD)
        era = below & (cluster_sizes <= CLUSTERSIZE_THRESHOLD)
        capt = int((can_cpl & dnn_fail_mask).sum()) if dnn_failed > 0 else 0
        at_risk = int((can_cpl & dnn_correct_mask).sum())
        est_net = capt - int(at_risk * 0.04)
        sign = '+' if est_net > 0 else ''
        print(f"  p{pct:>4} {thr:>10.4f} {int(can_cpl.sum()):>8,} {int(era.sum()):>6} {capt:>6} {at_risk:>8,} {sign}{est_net:>5}")

    sio.savemat(str(MAT_DIR / f'fig4_confidence_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'm_scores_all': m_arr,
        'm_scores_correct': correct_scores,
        'm_scores_failed': fail_scores,
        'dnn_failed': np.float64(dnn_failed),
        'N': np.float64(N),
        'clustersize_threshold': np.float64(CLUSTERSIZE_THRESHOLD),
    })
# Out:
# ======================================================================
# STAGE 2b: Confidence Analysis (clustersizethreshold=4)
# ======================================================================
#
#   m(M): mean=0.907909 median=0.920912 std=0.042359
#   Correct: mean=0.919191  Failed: mean=0.842062
#     Failure 1: m(M)=0.916253, percentile=18.4%
#     Failure 2: m(M)=0.615636, percentile=0.3%
#     Failure 3: m(M)=0.621288, percentile=0.3%
#     Failure 4: m(M)=0.855731, percentile=6.8%
#     Failure 5: m(M)=0.910753, percentile=15.8%
#     Failure 6: m(M)=0.837491, percentile=5.5%
#     Failure 7: m(M)=0.911827, percentile=16.2%
#     Failure 8: m(M)=0.707098, percentile=1.4%
#     Failure 9: m(M)=0.904512, percentile=13.9%
#     Failure 10: m(M)=0.915398, percentile=17.9%
#     Failure 11: m(M)=0.881515, percentile=9.7%
#     Failure 12: m(M)=0.766444, percentile=2.3%
#     Failure 13: m(M)=0.752788, percentile=2.0%
#     Failure 14: m(M)=0.878670, percentile=9.3%
#     Failure 15: m(M)=0.902302, percentile=13.3%
#     Failure 16: m(M)=0.660048, percentile=0.9%
#     Failure 17: m(M)=0.655908, percentile=0.8%
#     Failure 18: m(M)=0.917915, percentile=20.4%
#     Failure 19: m(M)=0.773141, percentile=2.5%
#     Failure 20: m(M)=0.791793, percentile=3.1%
#     Failure 21: m(M)=0.815547, percentile=4.1%
#     Failure 22: m(M)=0.885137, percentile=10.1%
#     Failure 23: m(M)=0.844270, percentile=5.8%
#     Failure 24: m(M)=0.919848, percentile=24.4%
#     Failure 25: m(M)=0.869653, percentile=8.3%
#     Failure 26: m(M)=0.866837, percentile=8.0%
#     Failure 27: m(M)=0.809251, percentile=3.8%
#     Failure 28: m(M)=0.819190, percentile=4.3%
#     Failure 29: m(M)=0.898902, percentile=12.6%
#     Failure 30: m(M)=0.682641, percentile=1.1%
#     Failure 31: m(M)=0.877776, percentile=9.2%
#     Failure 32: m(M)=0.812458, percentile=3.9%
#     Failure 33: m(M)=0.825470, percentile=4.8%
#     Failure 34: m(M)=0.629879, percentile=0.4%
#     Failure 35: m(M)=0.886958, percentile=10.3%
#     Failure 36: m(M)=0.704488, percentile=1.4%
#     Failure 37: m(M)=0.821132, percentile=4.4%
#     Failure 38: m(M)=0.782514, percentile=2.7%
#     Failure 39: m(M)=0.906724, percentile=14.4%
#     Failure 40: m(M)=0.583090, percentile=0.1%
#     Failure 41: m(M)=0.863520, percentile=7.6%
#     Failure 42: m(M)=0.673359, percentile=1.0%
#     Failure 43: m(M)=0.633851, percentile=0.5%
#     Failure 44: m(M)=0.843933, percentile=5.8%
#     Failure 45: m(M)=0.828081, percentile=4.9%
#     Failure 46: m(M)=0.730169, percentile=1.6%
#     Failure 47: m(M)=0.741750, percentile=1.8%
#     Failure 48: m(M)=0.811060, percentile=3.8%
#     Failure 49: m(M)=0.894565, percentile=11.6%
#     Failure 50: m(M)=0.632143, percentile=0.4%
#     Failure 51: m(M)=0.780171, percentile=2.7%
#     Failure 52: m(M)=0.914321, percentile=17.2%
#     Failure 53: m(M)=0.737286, percentile=1.8%
#     Failure 54: m(M)=0.840179, percentile=5.6%
#     Failure 55: m(M)=0.631291, percentile=0.4%
#     Failure 56: m(M)=0.910987, percentile=15.9%
#     Failure 57: m(M)=0.695859, percentile=1.3%
#     Failure 58: m(M)=0.807204, percentile=3.6%
#     Failure 59: m(M)=0.854224, percentile=6.6%
#     Failure 60: m(M)=0.802697, percentile=3.4%
#     Failure 61: m(M)=0.670090, percentile=1.0%
#     Failure 62: m(M)=0.833841, percentile=5.2%
#     Failure 63: m(M)=0.921251, percentile=78.4%
#     Failure 64: m(M)=0.809563, percentile=3.8%
#     Failure 65: m(M)=0.701814, percentile=1.4%
#     Failure 66: m(M)=0.903402, percentile=13.6%
#     Failure 67: m(M)=0.602721, percentile=0.2%
#     Failure 68: m(M)=0.798312, percentile=3.2%
#     Failure 69: m(M)=0.919461, percentile=23.1%
#     Failure 70: m(M)=0.774890, percentile=2.5%
#     Failure 71: m(M)=0.847236, percentile=6.1%
#     Failure 72: m(M)=0.905981, percentile=14.2%
#     Failure 73: m(M)=0.813410, percentile=4.0%
#     Failure 74: m(M)=0.857333, percentile=7.0%
#     Failure 75: m(M)=0.794617, percentile=3.1%
#     Failure 76: m(M)=0.757811, percentile=2.1%
#     Failure 77: m(M)=0.837454, percentile=5.4%
#     Failure 78: m(M)=0.807892, percentile=3.6%
#     Failure 79: m(M)=0.898835, percentile=12.6%
#     Failure 80: m(M)=0.605880, percentile=0.2%
#     Failure 81: m(M)=0.823995, percentile=4.6%
#     Failure 82: m(M)=0.897627, percentile=12.3%
#     Failure 83: m(M)=0.779117, percentile=2.6%
#     Failure 84: m(M)=0.824506, percentile=4.7%
#     Failure 85: m(M)=0.744924, percentile=1.9%
#     Failure 86: m(M)=0.670624, percentile=1.0%
#     Failure 87: m(M)=0.823148, percentile=4.6%
#     Failure 88: m(M)=0.770614, percentile=2.4%
#     Failure 89: m(M)=0.752983, percentile=2.0%
#     Failure 90: m(M)=0.645357, percentile=0.6%
#     Failure 91: m(M)=0.686073, percentile=1.2%
#     Failure 92: m(M)=0.913336, percentile=16.7%
#     Failure 93: m(M)=0.591750, percentile=0.1%
#     Failure 94: m(M)=0.717955, percentile=1.5%
#     Failure 95: m(M)=0.647374, percentile=0.7%
#     Failure 96: m(M)=0.902006, percentile=13.2%
#     Failure 97: m(M)=0.734741, percentile=1.7%
#     Failure 98: m(M)=0.808408, percentile=3.7%
#     Failure 99: m(M)=0.921025, percentile=59.7%
#     Failure 100: m(M)=0.856708, percentile=6.9%
#     Failure 101: m(M)=0.706144, percentile=1.4%
#     Failure 102: m(M)=0.746737, percentile=1.9%
#     Failure 103: m(M)=0.572972, percentile=0.0%
#     Failure 104: m(M)=0.586100, percentile=0.1%
#     Failure 105: m(M)=0.606809, percentile=0.2%
#     Failure 106: m(M)=0.818634, percentile=4.3%
#     Failure 107: m(M)=0.818305, percentile=4.3%
#     Failure 108: m(M)=0.628865, percentile=0.4%
#     Failure 109: m(M)=0.799301, percentile=3.3%
#     Failure 110: m(M)=0.887058, percentile=10.4%
#     Failure 111: m(M)=0.843620, percentile=5.8%
#     Failure 112: m(M)=0.772956, percentile=2.5%
#     Failure 113: m(M)=0.871678, percentile=8.6%
#     Failure 114: m(M)=0.802988, percentile=3.4%
#     Failure 115: m(M)=0.790184, percentile=3.0%
#     Failure 116: m(M)=0.894074, percentile=11.5%
#     Failure 117: m(M)=0.879780, percentile=9.4%
#     Failure 118: m(M)=0.859253, percentile=7.2%
#     Failure 119: m(M)=0.756078, percentile=2.0%
#     Failure 120: m(M)=0.669174, percentile=0.9%
#     Failure 121: m(M)=0.917439, percentile=19.8%
#     Failure 122: m(M)=0.901657, percentile=13.1%
#     Failure 123: m(M)=0.919592, percentile=23.6%
#     Failure 124: m(M)=0.885293, percentile=10.1%
#     Failure 125: m(M)=0.836688, percentile=5.4%
#     Failure 126: m(M)=0.905646, percentile=14.2%
#     Failure 127: m(M)=0.740294, percentile=1.8%
#     Failure 128: m(M)=0.653157, percentile=0.8%
#     Failure 129: m(M)=0.836631, percentile=5.4%
#     Failure 130: m(M)=0.903908, percentile=13.7%
#     Failure 131: m(M)=0.900169, percentile=12.8%
#     Failure 132: m(M)=0.620796, percentile=0.3%
#     Failure 133: m(M)=0.821039, percentile=4.4%
#     Failure 134: m(M)=0.792418, percentile=3.1%
#     Failure 135: m(M)=0.852314, percentile=6.4%
#     Failure 136: m(M)=0.890635, percentile=11.0%
#     Failure 137: m(M)=0.778972, percentile=2.6%
#     Failure 138: m(M)=0.917778, percentile=20.2%
#     Failure 139: m(M)=0.847451, percentile=6.1%
#     Failure 140: m(M)=0.566467, percentile=0.0%
#     Failure 141: m(M)=0.833215, percentile=5.2%
#     Failure 142: m(M)=0.711768, percentile=1.5%
#     Failure 143: m(M)=0.904250, percentile=13.8%
#     Failure 144: m(M)=0.906498, percentile=14.4%
#     Failure 145: m(M)=0.911128, percentile=16.0%
#     Failure 146: m(M)=0.916494, percentile=18.7%
#     Failure 147: m(M)=0.915164, percentile=17.7%
#     Failure 148: m(M)=0.901212, percentile=13.0%
#     Failure 149: m(M)=0.862384, percentile=7.4%
#     Failure 150: m(M)=0.884530, percentile=10.0%
#     Failure 151: m(M)=0.905570, percentile=14.2%
#     Failure 152: m(M)=0.808468, percentile=3.7%
#     Failure 153: m(M)=0.708338, percentile=1.4%
#     Failure 154: m(M)=0.849817, percentile=6.3%
#     Failure 155: m(M)=0.919730, percentile=24.0%
#     Failure 156: m(M)=0.613540, percentile=0.2%
#     Failure 157: m(M)=0.803867, percentile=3.4%
#     Failure 158: m(M)=0.916058, percentile=18.3%
#     Failure 159: m(M)=0.752240, percentile=1.9%
#     Failure 160: m(M)=0.607587, percentile=0.2%
#     Failure 161: m(M)=0.642780, percentile=0.6%
#     Failure 162: m(M)=0.854293, percentile=6.7%
#     Failure 163: m(M)=0.742930, percentile=1.8%
#     Failure 164: m(M)=0.921114, percentile=67.7%
#     Failure 165: m(M)=0.853275, percentile=6.6%
#     Failure 166: m(M)=0.916816, percentile=19.1%
#     Failure 167: m(M)=0.836499, percentile=5.4%
#     Failure 168: m(M)=0.859717, percentile=7.2%
#     Failure 169: m(M)=0.907149, percentile=14.6%
#     Failure 170: m(M)=0.892335, percentile=11.3%
#     Failure 171: m(M)=0.760097, percentile=2.1%
#     Failure 172: m(M)=0.718647, percentile=1.5%
#     Failure 173: m(M)=0.713324, percentile=1.5%
#     Failure 174: m(M)=0.855916, percentile=6.9%
#     Failure 175: m(M)=0.919780, percentile=24.2%
#     Failure 176: m(M)=0.857313, percentile=7.0%
#     Failure 177: m(M)=0.815025, percentile=4.1%
#     Failure 178: m(M)=0.858385, percentile=7.1%
#     Failure 179: m(M)=0.911260, percentile=16.0%
#     Failure 180: m(M)=0.900251, percentile=12.8%
#     Failure 181: m(M)=0.862695, percentile=7.5%
#     Failure 182: m(M)=0.879282, percentile=9.4%
#     Failure 183: m(M)=0.895125, percentile=11.7%
#     Failure 184: m(M)=0.919499, percentile=23.3%
#     Failure 185: m(M)=0.864654, percentile=7.7%
#     Failure 186: m(M)=0.838193, percentile=5.5%
#     Failure 187: m(M)=0.592153, percentile=0.1%
#     Failure 188: m(M)=0.857657, percentile=7.0%
#     Failure 189: m(M)=0.916646, percentile=18.9%
#     Failure 190: m(M)=0.894760, percentile=11.7%
#     Failure 191: m(M)=0.916077, percentile=18.3%
#     Failure 192: m(M)=0.844995, percentile=5.9%
#     Failure 193: m(M)=0.919353, percentile=22.9%
#     Failure 194: m(M)=0.920872, percentile=47.1%
#     Failure 195: m(M)=0.919495, percentile=23.3%
#     Failure 196: m(M)=0.907046, percentile=14.6%
#     Failure 197: m(M)=0.763471, percentile=2.2%
#     Failure 198: m(M)=0.877967, percentile=9.2%
#     Failure 199: m(M)=0.885467, percentile=10.1%
#     Failure 200: m(M)=0.917018, percentile=19.3%
#     Failure 201: m(M)=0.874692, percentile=8.9%
#     Failure 202: m(M)=0.916417, percentile=18.7%
#     Failure 203: m(M)=0.839699, percentile=5.6%
#     Failure 204: m(M)=0.825289, percentile=4.7%
#     Failure 205: m(M)=0.856429, percentile=6.9%
#     Failure 206: m(M)=0.910022, percentile=15.5%
#     Failure 207: m(M)=0.917279, percentile=19.6%
#     Failure 208: m(M)=0.824893, percentile=4.7%
#     Failure 209: m(M)=0.921562, percentile=91.9%
#     Failure 210: m(M)=0.873163, percentile=8.8%
#     Failure 211: m(M)=0.731824, percentile=1.7%
#     Failure 212: m(M)=0.909225, percentile=15.2%
#     Failure 213: m(M)=0.834290, percentile=5.2%
#     Failure 214: m(M)=0.823737, percentile=4.6%
#     Failure 215: m(M)=0.912429, percentile=16.4%
#     Failure 216: m(M)=0.874719, percentile=8.9%
#     Failure 217: m(M)=0.779760, percentile=2.6%
#     Failure 218: m(M)=0.883154, percentile=9.9%
#     Failure 219: m(M)=0.866619, percentile=8.0%
#     Failure 220: m(M)=0.793089, percentile=3.1%
#     Failure 221: m(M)=0.803376, percentile=3.4%
#     Failure 222: m(M)=0.809053, percentile=3.7%
#     Failure 223: m(M)=0.920975, percentile=55.1%
#     Failure 224: m(M)=0.847506, percentile=6.1%
#     Failure 225: m(M)=0.921059, percentile=62.8%
#     Failure 226: m(M)=0.680029, percentile=1.1%
#     Failure 227: m(M)=0.698507, percentile=1.3%
#     Failure 228: m(M)=0.861136, percentile=7.3%
#     Failure 229: m(M)=0.777526, percentile=2.6%
#     Failure 230: m(M)=0.867595, percentile=8.1%
#     Failure 231: m(M)=0.897727, percentile=12.3%
#     Failure 232: m(M)=0.750773, percentile=1.9%
#     Failure 233: m(M)=0.889157, percentile=10.7%
#     Failure 234: m(M)=0.906881, percentile=14.5%
#     Failure 235: m(M)=0.602148, percentile=0.2%
#     Failure 236: m(M)=0.859947, percentile=7.3%
#     Failure 237: m(M)=0.885985, percentile=10.2%
#     Failure 238: m(M)=0.819548, percentile=4.3%
#     Failure 239: m(M)=0.845545, percentile=6.0%
#     Failure 240: m(M)=0.921431, percentile=88.0%
#     Failure 241: m(M)=0.887471, percentile=10.4%
#     Failure 242: m(M)=0.889510, percentile=10.8%
#     Failure 243: m(M)=0.902433, percentile=13.4%
#     Failure 244: m(M)=0.918225, percentile=20.9%
#     Failure 245: m(M)=0.915650, percentile=18.0%
#     Failure 246: m(M)=0.921382, percentile=86.1%
#     Failure 247: m(M)=0.916500, percentile=18.8%
#     Failure 248: m(M)=0.879881, percentile=9.5%
#     Failure 249: m(M)=0.911261, percentile=16.0%
#     Failure 250: m(M)=0.866124, percentile=7.9%
#     Failure 251: m(M)=0.906772, percentile=14.5%
#     Failure 252: m(M)=0.596002, percentile=0.2%
#     Failure 253: m(M)=0.907113, percentile=14.6%
#     Failure 254: m(M)=0.802828, percentile=3.4%
#     Failure 255: m(M)=0.901346, percentile=13.0%
#     Failure 256: m(M)=0.898085, percentile=12.4%
#     Failure 257: m(M)=0.797417, percentile=3.2%
#     Failure 258: m(M)=0.875697, percentile=9.0%
#     Failure 259: m(M)=0.821609, percentile=4.5%
#     Failure 260: m(M)=0.901911, percentile=13.2%
#     Failure 261: m(M)=0.894535, percentile=11.6%
#     Failure 262: m(M)=0.920672, percentile=35.9%
#     Failure 263: m(M)=0.868790, percentile=8.2%
#     Failure 264: m(M)=0.850093, percentile=6.3%
#     Failure 265: m(M)=0.916056, percentile=18.3%
#     Failure 266: m(M)=0.921680, percentile=94.0%
#     Failure 267: m(M)=0.839068, percentile=5.5%
#     Failure 268: m(M)=0.846531, percentile=6.0%
#     Failure 269: m(M)=0.783321, percentile=2.8%
#     Failure 270: m(M)=0.912622, percentile=16.5%
#     Failure 271: m(M)=0.918139, percentile=20.8%
#     Failure 272: m(M)=0.891439, percentile=11.1%
#     Failure 273: m(M)=0.898976, percentile=12.6%
#     Failure 274: m(M)=0.858179, percentile=7.0%
#     Failure 275: m(M)=0.918201, percentile=20.9%
#     Failure 276: m(M)=0.870552, percentile=8.4%
#     Failure 277: m(M)=0.905131, percentile=14.1%
#     Failure 278: m(M)=0.919511, percentile=23.4%
#     Failure 279: m(M)=0.917980, percentile=20.5%
#     Failure 280: m(M)=0.907166, percentile=14.6%
#     Failure 281: m(M)=0.639047, percentile=0.6%
#     Failure 282: m(M)=0.919876, percentile=24.6%
#     Failure 283: m(M)=0.822392, percentile=4.5%
#     Failure 284: m(M)=0.899070, percentile=12.6%
#     Failure 285: m(M)=0.874013, percentile=8.9%
#     Failure 286: m(M)=0.848393, percentile=6.1%
#     Failure 287: m(M)=0.862901, percentile=7.5%
#     Failure 288: m(M)=0.915083, percentile=17.6%
#     Failure 289: m(M)=0.920058, percentile=25.7%
#     Failure 290: m(M)=0.870179, percentile=8.4%
#     Failure 291: m(M)=0.912809, percentile=16.6%
#     Failure 292: m(M)=0.836335, percentile=5.3%
#     Failure 293: m(M)=0.914470, percentile=17.2%
#     Failure 294: m(M)=0.771487, percentile=2.5%
#     Failure 295: m(M)=0.894270, percentile=11.6%
#     Failure 296: m(M)=0.837492, percentile=5.5%
#     Failure 297: m(M)=0.816850, percentile=4.2%
#     Failure 298: m(M)=0.918518, percentile=21.4%
#     Failure 299: m(M)=0.889533, percentile=10.8%
#     Failure 300: m(M)=0.767749, percentile=2.4%
#     Failure 301: m(M)=0.814185, percentile=4.0%
#     Failure 302: m(M)=0.769418, percentile=2.4%
#     Failure 303: m(M)=0.879637, percentile=9.4%
#     Failure 304: m(M)=0.806228, percentile=3.5%
#     Failure 305: m(M)=0.642007, percentile=0.6%
#     Failure 306: m(M)=0.867348, percentile=8.0%
#     Failure 307: m(M)=0.885461, percentile=10.1%
#     Failure 308: m(M)=0.921751, percentile=94.6%
#     Failure 309: m(M)=0.917902, percentile=20.4%
#     Failure 310: m(M)=0.916294, percentile=18.5%
#     Failure 311: m(M)=0.880380, percentile=9.5%
#     Failure 312: m(M)=0.885131, percentile=10.0%
#     Failure 313: m(M)=0.903038, percentile=13.5%
#     Failure 314: m(M)=0.842797, percentile=5.7%
#     Failure 315: m(M)=0.640442, percentile=0.6%
#     Failure 316: m(M)=0.821720, percentile=4.5%
#     Failure 317: m(M)=0.910854, percentile=15.9%
#     Failure 318: m(M)=0.843539, percentile=5.8%
#     Failure 319: m(M)=0.879781, percentile=9.5%
#     Failure 320: m(M)=0.829339, percentile=5.0%
#     Failure 321: m(M)=0.852299, percentile=6.4%
#     Failure 322: m(M)=0.918151, percentile=20.8%
#     Failure 323: m(M)=0.768808, percentile=2.4%
#     Failure 324: m(M)=0.844967, percentile=5.9%
#     Failure 325: m(M)=0.855258, percentile=6.8%
#     Failure 326: m(M)=0.896704, percentile=12.1%
#     Failure 327: m(M)=0.917736, percentile=20.1%
#     Failure 328: m(M)=0.917170, percentile=19.4%
#     Failure 329: m(M)=0.879255, percentile=9.4%
#     Failure 330: m(M)=0.917200, percentile=19.5%
#     Failure 331: m(M)=0.816366, percentile=4.1%
#     Failure 332: m(M)=0.831877, percentile=5.1%
#     Failure 333: m(M)=0.858305, percentile=7.1%
#     Failure 334: m(M)=0.908671, percentile=15.1%
#     Failure 335: m(M)=0.920478, percentile=30.0%
#     Failure 336: m(M)=0.896130, percentile=12.0%
#     Failure 337: m(M)=0.651551, percentile=0.7%
#     Failure 338: m(M)=0.897857, percentile=12.3%
#     Failure 339: m(M)=0.906736, percentile=14.4%
#     Failure 340: m(M)=0.838407, percentile=5.5%
#     Failure 341: m(M)=0.872676, percentile=8.6%
#     Failure 342: m(M)=0.906742, percentile=14.4%
#     Failure 343: m(M)=0.914231, percentile=17.1%
#     Failure 344: m(M)=0.897392, percentile=12.2%
#     Failure 345: m(M)=0.875245, percentile=9.0%
#     Failure 346: m(M)=0.917324, percentile=19.6%
#     Failure 347: m(M)=0.909354, percentile=15.3%
#     Failure 348: m(M)=0.901462, percentile=13.1%
#     Failure 349: m(M)=0.838621, percentile=5.5%
#     Failure 350: m(M)=0.831374, percentile=5.1%
#     Failure 351: m(M)=0.807709, percentile=3.6%
#     Failure 352: m(M)=0.907441, percentile=14.7%
#     Failure 353: m(M)=0.918854, percentile=21.9%
#     Failure 354: m(M)=0.877247, percentile=9.2%
#     Failure 355: m(M)=0.918184, percentile=20.9%
#     Failure 356: m(M)=0.896537, percentile=12.1%
#     Failure 357: m(M)=0.695058, percentile=1.3%
#     Failure 358: m(M)=0.804254, percentile=3.5%
#     Failure 359: m(M)=0.874021, percentile=8.9%
#     Failure 360: m(M)=0.865693, percentile=7.9%
#     Failure 361: m(M)=0.864387, percentile=7.7%
#     Failure 362: m(M)=0.861664, percentile=7.4%
#     Failure 363: m(M)=0.902680, percentile=13.4%
#     Failure 364: m(M)=0.860364, percentile=7.3%
#     Failure 365: m(M)=0.897652, percentile=12.3%
#     Failure 366: m(M)=0.918309, percentile=21.0%
#     Failure 367: m(M)=0.821066, percentile=4.4%
#     Failure 368: m(M)=0.905212, percentile=14.1%
#     Failure 369: m(M)=0.902638, percentile=13.4%
#     Failure 370: m(M)=0.799278, percentile=3.2%
#     Failure 371: m(M)=0.891007, percentile=11.1%
#     Failure 372: m(M)=0.854827, percentile=6.7%
#     Failure 373: m(M)=0.917779, percentile=20.2%
#     Failure 374: m(M)=0.839492, percentile=5.6%
#     Failure 375: m(M)=0.807309, percentile=3.6%
#     Failure 376: m(M)=0.801830, percentile=3.3%
#     Failure 377: m(M)=0.754456, percentile=2.0%
#     Failure 378: m(M)=0.805653, percentile=3.5%
#     Failure 379: m(M)=0.898951, percentile=12.6%
#     Failure 380: m(M)=0.790289, percentile=3.0%
#     Failure 381: m(M)=0.852382, percentile=6.5%
#     Failure 382: m(M)=0.887541, percentile=10.4%
#     Failure 383: m(M)=0.632716, percentile=0.4%
#     Failure 384: m(M)=0.821283, percentile=4.5%
#     Failure 385: m(M)=0.865324, percentile=7.8%
#     Failure 386: m(M)=0.890884, percentile=11.0%
#     Failure 387: m(M)=0.901378, percentile=13.1%
#     Failure 388: m(M)=0.789157, percentile=3.0%
#     Failure 389: m(M)=0.733477, percentile=1.7%
#     Failure 390: m(M)=0.780460, percentile=2.7%
#     Failure 391: m(M)=0.919450, percentile=23.1%
#     Failure 392: m(M)=0.906403, percentile=14.3%
#     Failure 393: m(M)=0.907955, percentile=14.9%
#     Failure 394: m(M)=0.865212, percentile=7.8%
#     Failure 395: m(M)=0.884635, percentile=10.0%
#     Failure 396: m(M)=0.920931, percentile=51.4%
#     Failure 397: m(M)=0.895131, percentile=11.8%
#     Failure 398: m(M)=0.806555, percentile=3.6%
#     Failure 399: m(M)=0.875824, percentile=9.0%
#     Failure 400: m(M)=0.913107, percentile=16.7%
#     Failure 401: m(M)=0.907586, percentile=14.7%
#     Failure 402: m(M)=0.876920, percentile=9.1%
#     Failure 403: m(M)=0.879664, percentile=9.4%
#     Failure 404: m(M)=0.731961, percentile=1.7%
#     Failure 405: m(M)=0.907854, percentile=14.8%
#     Failure 406: m(M)=0.901485, percentile=13.1%
#     Failure 407: m(M)=0.907174, percentile=14.6%
#     Failure 408: m(M)=0.817910, percentile=4.2%
#     Failure 409: m(M)=0.918006, percentile=20.5%
#     Failure 410: m(M)=0.918584, percentile=21.5%
#     Failure 411: m(M)=0.867536, percentile=8.1%
#     Failure 412: m(M)=0.920631, percentile=34.4%
#     Failure 413: m(M)=0.860215, percentile=7.3%
#     Failure 414: m(M)=0.920701, percentile=37.1%
#     Failure 415: m(M)=0.891889, percentile=11.2%
#     Failure 416: m(M)=0.694299, percentile=1.3%
#     Failure 417: m(M)=0.798849, percentile=3.2%
#     Failure 418: m(M)=0.798546, percentile=3.2%
#     Failure 419: m(M)=0.915263, percentile=17.7%
#     Failure 420: m(M)=0.904244, percentile=13.8%
#     Failure 421: m(M)=0.865961, percentile=7.9%
#     Failure 422: m(M)=0.921133, percentile=69.3%
#     Failure 423: m(M)=0.849446, percentile=6.2%
#     Failure 424: m(M)=0.871259, percentile=8.5%
#     Failure 425: m(M)=0.903637, percentile=13.7%
#     Failure 426: m(M)=0.878509, percentile=9.3%
#     Failure 427: m(M)=0.865404, percentile=7.9%
#     Failure 428: m(M)=0.863971, percentile=7.6%
#     Failure 429: m(M)=0.895427, percentile=11.8%
#     Failure 430: m(M)=0.899805, percentile=12.8%
#     Failure 431: m(M)=0.903567, percentile=13.7%
#     Failure 432: m(M)=0.869428, percentile=8.3%
#     Failure 433: m(M)=0.821258, percentile=4.4%
#     Failure 434: m(M)=0.881566, percentile=9.7%
#     Failure 435: m(M)=0.760799, percentile=2.1%
#     Failure 436: m(M)=0.768498, percentile=2.4%
#     Failure 437: m(M)=0.858915, percentile=7.2%
#     Failure 438: m(M)=0.893818, percentile=11.5%
#     Failure 439: m(M)=0.921472, percentile=89.3%
#     Failure 440: m(M)=0.780260, percentile=2.7%
#     Failure 441: m(M)=0.911802, percentile=16.2%
#     Failure 442: m(M)=0.812975, percentile=3.9%
#     Failure 443: m(M)=0.918668, percentile=21.6%
#     Failure 444: m(M)=0.864554, percentile=7.7%
#     Failure 445: m(M)=0.786996, percentile=2.9%
#     Failure 446: m(M)=0.918888, percentile=22.0%
#     Failure 447: m(M)=0.850079, percentile=6.3%
#     Failure 448: m(M)=0.909366, percentile=15.3%
#     Failure 449: m(M)=0.886773, percentile=10.3%
#     Failure 450: m(M)=0.806770, percentile=3.6%
#     Failure 451: m(M)=0.838031, percentile=5.5%
#     Failure 452: m(M)=0.919980, percentile=25.2%
#     Failure 453: m(M)=0.892092, percentile=11.2%
#     Failure 454: m(M)=0.853831, percentile=6.6%
#     Failure 455: m(M)=0.888983, percentile=10.7%
#     Failure 456: m(M)=0.685564, percentile=1.1%
#     Failure 457: m(M)=0.636545, percentile=0.5%
#     Failure 458: m(M)=0.865210, percentile=7.8%
#     Failure 459: m(M)=0.863129, percentile=7.5%
#     Failure 460: m(M)=0.851632, percentile=6.4%
#     Failure 461: m(M)=0.879939, percentile=9.5%
#     Failure 462: m(M)=0.862063, percentile=7.4%
#     Failure 463: m(M)=0.906631, percentile=14.4%
#     Failure 464: m(M)=0.883645, percentile=9.9%
#     Failure 465: m(M)=0.920566, percentile=32.2%
#     Failure 466: m(M)=0.770903, percentile=2.5%
#     Failure 467: m(M)=0.895567, percentile=11.9%
#     Failure 468: m(M)=0.920313, percentile=27.6%
#     Failure 469: m(M)=0.878454, percentile=9.3%
#     Failure 470: m(M)=0.847304, percentile=6.1%
#     Failure 471: m(M)=0.888860, percentile=10.7%
#     Failure 472: m(M)=0.887429, percentile=10.4%
#     Failure 473: m(M)=0.848469, percentile=6.2%
#     Failure 474: m(M)=0.915550, percentile=17.9%
#     Failure 475: m(M)=0.851991, percentile=6.4%
#     Failure 476: m(M)=0.902975, percentile=13.5%
#     Failure 477: m(M)=0.825909, percentile=4.8%
#     Failure 478: m(M)=0.817679, percentile=4.2%
#     Failure 479: m(M)=0.845535, percentile=5.9%
#     Failure 480: m(M)=0.903545, percentile=13.6%
#     Failure 481: m(M)=0.721897, percentile=1.5%
#     Failure 482: m(M)=0.905941, percentile=14.2%
#     Failure 483: m(M)=0.919073, percentile=22.4%
#     Failure 484: m(M)=0.837076, percentile=5.4%
#     Failure 485: m(M)=0.815300, percentile=4.1%
#     Failure 486: m(M)=0.906756, percentile=14.5%
#     Failure 487: m(M)=0.884022, percentile=10.0%
#     Failure 488: m(M)=0.882370, percentile=9.8%
#     Failure 489: m(M)=0.827254, percentile=4.9%
#     Failure 490: m(M)=0.732521, percentile=1.7%
#     Failure 491: m(M)=0.919223, percentile=22.6%
#     Failure 492: m(M)=0.903099, percentile=13.5%
#     Failure 493: m(M)=0.911203, percentile=16.0%
#     Failure 494: m(M)=0.825783, percentile=4.8%
#     Failure 495: m(M)=0.919796, percentile=24.2%
#     Failure 496: m(M)=0.717934, percentile=1.5%
#     Failure 497: m(M)=0.844691, percentile=5.9%
#     Failure 498: m(M)=0.867786, percentile=8.1%
#     Failure 499: m(M)=0.900252, percentile=12.8%
#     Failure 500: m(M)=0.899758, percentile=12.7%
#     Failure 501: m(M)=0.918292, percentile=21.0%
#     Failure 502: m(M)=0.893591, percentile=11.4%
#     Failure 503: m(M)=0.887397, percentile=10.4%
#     Failure 504: m(M)=0.879793, percentile=9.5%
#     Failure 505: m(M)=0.827190, percentile=4.9%
#     Failure 506: m(M)=0.897453, percentile=12.3%
#     Failure 507: m(M)=0.861782, percentile=7.4%
#     Failure 508: m(M)=0.833234, percentile=5.2%
#     Failure 509: m(M)=0.898917, percentile=12.6%
#     Failure 510: m(M)=0.901728, percentile=13.1%
#     Failure 511: m(M)=0.918382, percentile=21.1%
#     Failure 512: m(M)=0.914241, percentile=17.1%
#     Failure 513: m(M)=0.899179, percentile=12.6%
#     Failure 514: m(M)=0.875275, percentile=9.0%
#     Failure 515: m(M)=0.854556, percentile=6.7%
#     Failure 516: m(M)=0.643464, percentile=0.6%
#     Failure 517: m(M)=0.885739, percentile=10.1%
#     Failure 518: m(M)=0.860328, percentile=7.3%
#     Failure 519: m(M)=0.848854, percentile=6.2%
#     Failure 520: m(M)=0.829755, percentile=5.0%
#     Failure 521: m(M)=0.724163, percentile=1.6%
#     Failure 522: m(M)=0.851705, percentile=6.4%
#     Failure 523: m(M)=0.821333, percentile=4.5%
#     Failure 524: m(M)=0.795342, percentile=3.1%
#     Failure 525: m(M)=0.620122, percentile=0.3%
#     Failure 526: m(M)=0.689262, percentile=1.2%
#     Failure 527: m(M)=0.627262, percentile=0.4%
#     Failure 528: m(M)=0.882070, percentile=9.7%
#     Failure 529: m(M)=0.920986, percentile=56.0%
#     Failure 530: m(M)=0.725012, percentile=1.6%
#     Failure 531: m(M)=0.757003, percentile=2.1%
#     Failure 532: m(M)=0.865934, percentile=7.9%
#     Failure 533: m(M)=0.919618, percentile=23.7%
#     Failure 534: m(M)=0.778375, percentile=2.6%
#     Failure 535: m(M)=0.899548, percentile=12.7%
#     Failure 536: m(M)=0.807621, percentile=3.6%
#     Failure 537: m(M)=0.920946, percentile=52.6%
#     Failure 538: m(M)=0.909997, percentile=15.5%
#     Failure 539: m(M)=0.702655, percentile=1.4%
#     Failure 540: m(M)=0.813497, percentile=4.0%
#     Failure 541: m(M)=0.785603, percentile=2.8%
#     Failure 542: m(M)=0.844483, percentile=5.9%
#     Failure 543: m(M)=0.917722, percentile=20.1%
#     Failure 544: m(M)=0.859993, percentile=7.3%
#     Failure 545: m(M)=0.817057, percentile=4.2%
#     Failure 546: m(M)=0.900740, percentile=12.9%
#     Failure 547: m(M)=0.906918, percentile=14.5%
#     Failure 548: m(M)=0.919238, percentile=22.7%
#     Failure 549: m(M)=0.906455, percentile=14.4%
#     Failure 550: m(M)=0.816203, percentile=4.1%
#     Failure 551: m(M)=0.915419, percentile=17.9%
#     Failure 552: m(M)=0.922130, percentile=96.6%
#     Failure 553: m(M)=0.902942, percentile=13.5%
#     Failure 554: m(M)=0.705188, percentile=1.4%
#     Failure 555: m(M)=0.872305, percentile=8.6%
#     Failure 556: m(M)=0.897778, percentile=12.3%
#     Failure 557: m(M)=0.761149, percentile=2.2%
#     Failure 558: m(M)=0.845714, percentile=6.0%
#     Failure 559: m(M)=0.787641, percentile=2.9%
#     Failure 560: m(M)=0.801568, percentile=3.3%
#     Failure 561: m(M)=0.845812, percentile=6.0%
#     Failure 562: m(M)=0.682571, percentile=1.1%
#     Failure 563: m(M)=0.837304, percentile=5.4%
#     Failure 564: m(M)=0.804206, percentile=3.5%
#     Failure 565: m(M)=0.855085, percentile=6.8%
#     Failure 566: m(M)=0.906492, percentile=14.4%
#     Failure 567: m(M)=0.907458, percentile=14.7%
#     Failure 568: m(M)=0.865927, percentile=7.9%
#     Failure 569: m(M)=0.696316, percentile=1.3%
#     Failure 570: m(M)=0.828847, percentile=4.9%
#     Failure 571: m(M)=0.663494, percentile=0.9%
#     Failure 572: m(M)=0.782923, percentile=2.8%
#     Failure 573: m(M)=0.582088, percentile=0.1%
#     Failure 574: m(M)=0.920517, percentile=31.0%
#     Failure 575: m(M)=0.756065, percentile=2.0%
#     Failure 576: m(M)=0.866071, percentile=7.9%
#     Failure 577: m(M)=0.718048, percentile=1.5%
#     Failure 578: m(M)=0.901880, percentile=13.2%
#     Failure 579: m(M)=0.743889, percentile=1.9%
#     Failure 580: m(M)=0.918110, percentile=20.7%
#     Failure 581: m(M)=0.795487, percentile=3.1%
#     Failure 582: m(M)=0.894748, percentile=11.7%
#     Failure 583: m(M)=0.831535, percentile=5.1%
#     Failure 584: m(M)=0.872840, percentile=8.7%
#     Failure 585: m(M)=0.905099, percentile=14.0%
#     Failure 586: m(M)=0.894117, percentile=11.5%
#     Failure 587: m(M)=0.890028, percentile=10.8%
#     Failure 588: m(M)=0.863017, percentile=7.5%
#     Failure 589: m(M)=0.911287, percentile=16.0%
#     Failure 590: m(M)=0.825338, percentile=4.8%
#     Failure 591: m(M)=0.888708, percentile=10.6%
#     Failure 592: m(M)=0.832028, percentile=5.1%
#     Failure 593: m(M)=0.689783, percentile=1.2%
#     Failure 594: m(M)=0.854830, percentile=6.7%
#     Failure 595: m(M)=0.865058, percentile=7.8%
#     Failure 596: m(M)=0.765793, percentile=2.3%
#     Failure 597: m(M)=0.843539, percentile=5.8%
#     Failure 598: m(M)=0.910075, percentile=15.5%
#     Failure 599: m(M)=0.788343, percentile=3.0%
#     Failure 600: m(M)=0.909076, percentile=15.2%
#     Failure 601: m(M)=0.831488, percentile=5.1%
#     Failure 602: m(M)=0.914546, percentile=17.3%
#     Failure 603: m(M)=0.801170, percentile=3.3%
#     Failure 604: m(M)=0.869185, percentile=8.2%
#     Failure 605: m(M)=0.910874, percentile=15.9%
#     Failure 606: m(M)=0.831026, percentile=5.1%
#     Failure 607: m(M)=0.786922, percentile=2.9%
#     Failure 608: m(M)=0.907978, percentile=14.9%
#     Failure 609: m(M)=0.920371, percentile=28.4%
#     Failure 610: m(M)=0.721642, percentile=1.5%
#     Failure 611: m(M)=0.878152, percentile=9.3%
#     Failure 612: m(M)=0.815436, percentile=4.1%
#     Failure 613: m(M)=0.815306, percentile=4.1%
#     Failure 614: m(M)=0.747762, percentile=1.9%
#     Failure 615: m(M)=0.878669, percentile=9.3%
#     Failure 616: m(M)=0.907064, percentile=14.6%
#     Failure 617: m(M)=0.836272, percentile=5.3%
#     Failure 618: m(M)=0.854848, percentile=6.7%
#     Failure 619: m(M)=0.901755, percentile=13.2%
#     Failure 620: m(M)=0.811062, percentile=3.8%
#     Failure 621: m(M)=0.739357, percentile=1.8%
#     Failure 622: m(M)=0.859256, percentile=7.2%
#     Failure 623: m(M)=0.919990, percentile=25.2%
#     Failure 624: m(M)=0.841891, percentile=5.7%
#     Failure 625: m(M)=0.740526, percentile=1.8%
#     Failure 626: m(M)=0.920016, percentile=25.4%
#     Failure 627: m(M)=0.872955, percentile=8.8%
#     Failure 628: m(M)=0.791022, percentile=3.0%
#     Failure 629: m(M)=0.901902, percentile=13.2%
#     Failure 630: m(M)=0.920433, percentile=29.3%
#     Failure 631: m(M)=0.890916, percentile=11.0%
#     Failure 632: m(M)=0.771156, percentile=2.5%
#     Failure 633: m(M)=0.789948, percentile=3.0%
#     Failure 634: m(M)=0.670312, percentile=1.0%
#     Failure 635: m(M)=0.871927, percentile=8.6%
#     Failure 636: m(M)=0.878094, percentile=9.2%
#     Failure 637: m(M)=0.775380, percentile=2.5%
#     Failure 638: m(M)=0.904392, percentile=13.9%
#     Failure 639: m(M)=0.910840, percentile=15.8%
#     Failure 640: m(M)=0.897362, percentile=12.2%
#     Failure 641: m(M)=0.902139, percentile=13.3%
#     Failure 642: m(M)=0.641659, percentile=0.6%
#     Failure 643: m(M)=0.853132, percentile=6.5%
#     Failure 644: m(M)=0.920697, percentile=36.8%
#     Failure 645: m(M)=0.635059, percentile=0.5%
#     Failure 646: m(M)=0.923952, percentile=98.8%
#     Failure 647: m(M)=0.846123, percentile=6.0%
#     Failure 648: m(M)=0.881843, percentile=9.7%
#     Failure 649: m(M)=0.901392, percentile=13.1%
#     Failure 650: m(M)=0.916031, percentile=18.2%
#     Failure 651: m(M)=0.577782, percentile=0.1%
#     Failure 652: m(M)=0.722456, percentile=1.6%
#     Failure 653: m(M)=0.618155, percentile=0.3%
#     Failure 654: m(M)=0.894667, percentile=11.7%
#     Failure 655: m(M)=0.673477, percentile=1.0%
#     Failure 656: m(M)=0.698497, percentile=1.3%
#     Failure 657: m(M)=0.901801, percentile=13.2%
#     Failure 658: m(M)=0.838421, percentile=5.5%
#     Failure 659: m(M)=0.646152, percentile=0.7%
#     Failure 660: m(M)=0.817882, percentile=4.2%
#     Failure 661: m(M)=0.844158, percentile=5.8%
#     Failure 662: m(M)=0.701428, percentile=1.3%
#     Failure 663: m(M)=0.704871, percentile=1.4%
#     Failure 664: m(M)=0.804341, percentile=3.5%
#     Failure 665: m(M)=0.818009, percentile=4.2%
#     Failure 666: m(M)=0.858510, percentile=7.1%
#     Failure 667: m(M)=0.837005, percentile=5.4%
#     Failure 668: m(M)=0.909017, percentile=15.1%
#     Failure 669: m(M)=0.600118, percentile=0.2%
#     Failure 670: m(M)=0.907921, percentile=14.8%
#     Failure 671: m(M)=0.912428, percentile=16.4%
#     Failure 672: m(M)=0.842657, percentile=5.7%
#     Failure 673: m(M)=0.902917, percentile=13.5%
#     Failure 674: m(M)=0.717278, percentile=1.5%
#     Failure 675: m(M)=0.881158, percentile=9.6%
#     Failure 676: m(M)=0.794304, percentile=3.1%
#     Failure 677: m(M)=0.762443, percentile=2.2%
#     Failure 678: m(M)=0.677382, percentile=1.0%
#     Failure 679: m(M)=0.888526, percentile=10.6%
#     Failure 680: m(M)=0.808775, percentile=3.7%
#     Failure 681: m(M)=0.891852, percentile=11.2%
#     Failure 682: m(M)=0.622586, percentile=0.3%
#     Failure 683: m(M)=0.913710, percentile=16.8%
#     Failure 684: m(M)=0.801286, percentile=3.3%
#     Failure 685: m(M)=0.657028, percentile=0.8%
#     Failure 686: m(M)=0.906233, percentile=14.3%
#     Failure 687: m(M)=0.917128, percentile=19.4%
#     Failure 688: m(M)=0.845122, percentile=5.9%
#     Failure 689: m(M)=0.918763, percentile=21.8%
#     Failure 690: m(M)=0.797905, percentile=3.2%
#     Failure 691: m(M)=0.876912, percentile=9.1%
#     Failure 692: m(M)=0.909091, percentile=15.2%
#     Failure 693: m(M)=0.910486, percentile=15.6%
#     Failure 694: m(M)=0.916055, percentile=18.2%
#     Failure 695: m(M)=0.892247, percentile=11.2%
#     Failure 696: m(M)=0.904998, percentile=14.0%
#     Failure 697: m(M)=0.891111, percentile=11.1%
#     Failure 698: m(M)=0.883850, percentile=9.9%
#     Failure 699: m(M)=0.917894, percentile=20.3%
#     Failure 700: m(M)=0.635747, percentile=0.5%
#     Failure 701: m(M)=0.723094, percentile=1.6%
#     Failure 702: m(M)=0.896022, percentile=11.9%
#     Failure 703: m(M)=0.780848, percentile=2.7%
#     Failure 704: m(M)=0.918540, percentile=21.4%
#     Failure 705: m(M)=0.742864, percentile=1.8%
#     Failure 706: m(M)=0.769625, percentile=2.4%
#     Failure 707: m(M)=0.688965, percentile=1.2%
#     Failure 708: m(M)=0.860807, percentile=7.3%
#     Failure 709: m(M)=0.898432, percentile=12.5%
#     Failure 710: m(M)=0.914796, percentile=17.4%
#     Failure 711: m(M)=0.918675, percentile=21.6%
#     Failure 712: m(M)=0.890245, percentile=10.9%
#     Failure 713: m(M)=0.866209, percentile=7.9%
#     Failure 714: m(M)=0.916384, percentile=18.6%
#     Failure 715: m(M)=0.756286, percentile=2.0%
#     Failure 716: m(M)=0.872808, percentile=8.7%
#     Failure 717: m(M)=0.888916, percentile=10.7%
#     Failure 718: m(M)=0.916152, percentile=18.3%
#     Failure 719: m(M)=0.909302, percentile=15.2%
#     Failure 720: m(M)=0.864864, percentile=7.7%
#     Failure 721: m(M)=0.822955, percentile=4.6%
#     Failure 722: m(M)=0.815705, percentile=4.1%
#     Failure 723: m(M)=0.920612, percentile=33.7%
#     Failure 724: m(M)=0.898524, percentile=12.5%
#     Failure 725: m(M)=0.690977, percentile=1.2%
#     Failure 726: m(M)=0.789294, percentile=3.0%
#     Failure 727: m(M)=0.837859, percentile=5.5%
#     Failure 728: m(M)=0.824020, percentile=4.7%
#     Failure 729: m(M)=0.896584, percentile=12.1%
#     Failure 730: m(M)=0.901084, percentile=13.0%
#     Failure 731: m(M)=0.920832, percentile=44.6%
#     Failure 732: m(M)=0.843058, percentile=5.8%
#     Failure 733: m(M)=0.907805, percentile=14.8%
#     Failure 734: m(M)=0.885995, percentile=10.2%
#     Failure 735: m(M)=0.826031, percentile=4.8%
#     Failure 736: m(M)=0.913644, percentile=16.8%
#     Failure 737: m(M)=0.684689, percentile=1.1%
#     Failure 738: m(M)=0.917451, percentile=19.8%
#     Failure 739: m(M)=0.915143, percentile=17.7%
#     Failure 740: m(M)=0.870235, percentile=8.4%
#     Failure 741: m(M)=0.700084, percentile=1.3%
#     Failure 742: m(M)=0.895857, percentile=11.9%
#     Failure 743: m(M)=0.757836, percentile=2.1%
#     Failure 744: m(M)=0.830502, percentile=5.0%
#     Failure 745: m(M)=0.828512, percentile=4.9%
#     Failure 746: m(M)=0.617871, percentile=0.3%
#     Failure 747: m(M)=0.858879, percentile=7.1%
#     Failure 748: m(M)=0.820176, percentile=4.3%
#     Failure 749: m(M)=0.776295, percentile=2.6%
#     Failure 750: m(M)=0.919818, percentile=24.3%
#     Failure 751: m(M)=0.911936, percentile=16.2%
#     Failure 752: m(M)=0.853763, percentile=6.6%
#     Failure 753: m(M)=0.773493, percentile=2.5%
#     Failure 754: m(M)=0.909510, percentile=15.4%
#     Failure 755: m(M)=0.858248, percentile=7.0%
#     Failure 756: m(M)=0.836361, percentile=5.3%
#     Failure 757: m(M)=0.903092, percentile=13.5%
#     Failure 758: m(M)=0.820595, percentile=4.4%
#     Failure 759: m(M)=0.782321, percentile=2.7%
#     Failure 760: m(M)=0.836425, percentile=5.3%
#     Failure 761: m(M)=0.898681, percentile=12.5%
#     Failure 762: m(M)=0.830721, percentile=5.0%
#     Failure 763: m(M)=0.833922, percentile=5.2%
#     Failure 764: m(M)=0.855321, percentile=6.8%
#     Failure 765: m(M)=0.899760, percentile=12.7%
#     Failure 766: m(M)=0.920824, percentile=44.1%
#     Failure 767: m(M)=0.915036, percentile=17.5%
#     Failure 768: m(M)=0.826507, percentile=4.8%
#     Failure 769: m(M)=0.886587, percentile=10.2%
#     Failure 770: m(M)=0.878248, percentile=9.3%
#     Failure 771: m(M)=0.918889, percentile=22.0%
#     Failure 772: m(M)=0.592536, percentile=0.2%
#     Failure 773: m(M)=0.813556, percentile=4.0%
#     Failure 774: m(M)=0.914709, percentile=17.3%
#     Failure 775: m(M)=0.857454, percentile=7.0%
#     Failure 776: m(M)=0.914622, percentile=17.3%
#     Failure 777: m(M)=0.882606, percentile=9.8%
#     Failure 778: m(M)=0.918836, percentile=21.9%
#     Failure 779: m(M)=0.921385, percentile=86.2%
#     Failure 780: m(M)=0.834682, percentile=5.3%
#     Failure 781: m(M)=0.614237, percentile=0.3%
#     Failure 782: m(M)=0.710666, percentile=1.4%
#     Failure 783: m(M)=0.811216, percentile=3.8%
#     Failure 784: m(M)=0.920086, percentile=25.8%
#     Failure 785: m(M)=0.875265, percentile=9.0%
#     Failure 786: m(M)=0.836617, percentile=5.4%
#     Failure 787: m(M)=0.826651, percentile=4.8%
#     Failure 788: m(M)=0.912314, percentile=16.3%
#     Failure 789: m(M)=0.841345, percentile=5.7%
#     Failure 790: m(M)=0.871408, percentile=8.6%
#     Failure 791: m(M)=0.913769, percentile=16.8%
#     Failure 792: m(M)=0.866671, percentile=8.0%
#     Failure 793: m(M)=0.919905, percentile=24.7%
#     Failure 794: m(M)=0.886420, percentile=10.2%
#     Failure 795: m(M)=0.856020, percentile=6.9%
#     Failure 796: m(M)=0.920652, percentile=35.1%
#     Failure 797: m(M)=0.620105, percentile=0.3%
#     Failure 798: m(M)=0.894967, percentile=11.7%
#     Failure 799: m(M)=0.855696, percentile=6.8%
#     Failure 800: m(M)=0.885171, percentile=10.1%
#     Failure 801: m(M)=0.666653, percentile=0.9%
#     Failure 802: m(M)=0.816461, percentile=4.2%
#     Failure 803: m(M)=0.858833, percentile=7.1%
#     Failure 804: m(M)=0.852929, percentile=6.5%
#     Failure 805: m(M)=0.872898, percentile=8.7%
#     Failure 806: m(M)=0.821333, percentile=4.5%
#     Failure 807: m(M)=0.895777, percentile=11.9%
#     Failure 808: m(M)=0.847973, percentile=6.1%
#     Failure 809: m(M)=0.849794, percentile=6.2%
#     Failure 810: m(M)=0.901422, percentile=13.1%
#     Failure 811: m(M)=0.882833, percentile=9.8%
#     Failure 812: m(M)=0.782197, percentile=2.7%
#     Failure 813: m(M)=0.918940, percentile=22.1%
#     Failure 814: m(M)=0.892940, percentile=11.3%
#     Failure 815: m(M)=0.912641, percentile=16.5%
#     Failure 816: m(M)=0.833034, percentile=5.2%
#     Failure 817: m(M)=0.919947, percentile=25.0%
#     Failure 818: m(M)=0.893116, percentile=11.4%
#     Failure 819: m(M)=0.894906, percentile=11.7%
#     Failure 820: m(M)=0.916446, percentile=18.7%
#     Failure 821: m(M)=0.859310, percentile=7.2%
#     Failure 822: m(M)=0.884826, percentile=10.0%
#     Failure 823: m(M)=0.875303, percentile=9.0%
#     Failure 824: m(M)=0.826555, percentile=4.8%
#     Failure 825: m(M)=0.785170, percentile=2.8%
#     Failure 826: m(M)=0.876353, percentile=9.1%
#     Failure 827: m(M)=0.898894, percentile=12.6%
#     Failure 828: m(M)=0.919833, percentile=24.4%
#     Failure 829: m(M)=0.864735, percentile=7.7%
#     Failure 830: m(M)=0.631178, percentile=0.4%
#     Failure 831: m(M)=0.882983, percentile=9.8%
#     Failure 832: m(M)=0.904541, percentile=13.9%
#     Failure 833: m(M)=0.906305, percentile=14.3%
#     Failure 834: m(M)=0.855032, percentile=6.7%
#     Failure 835: m(M)=0.910675, percentile=15.7%
#     Failure 836: m(M)=0.858306, percentile=7.1%
#     Failure 837: m(M)=0.904399, percentile=13.9%
#     Failure 838: m(M)=0.858740, percentile=7.1%
#     Failure 839: m(M)=0.799703, percentile=3.3%
#     Failure 840: m(M)=0.917718, percentile=20.1%
#     Failure 841: m(M)=0.722209, percentile=1.6%
#     Failure 842: m(M)=0.913014, percentile=16.6%
#     Failure 843: m(M)=0.920675, percentile=36.1%
#     Failure 844: m(M)=0.919693, percentile=23.9%
#     Failure 845: m(M)=0.683942, percentile=1.1%
#     Failure 846: m(M)=0.893319, percentile=11.4%
#     Failure 847: m(M)=0.763121, percentile=2.2%
#     Failure 848: m(M)=0.824038, percentile=4.7%
#     Failure 849: m(M)=0.884201, percentile=10.0%
#     Failure 850: m(M)=0.879365, percentile=9.4%
#     Failure 851: m(M)=0.763704, percentile=2.2%
#     Failure 852: m(M)=0.802675, percentile=3.4%
#     Failure 853: m(M)=0.900996, percentile=13.0%
#     Failure 854: m(M)=0.916780, percentile=19.0%
#     Failure 855: m(M)=0.844275, percentile=5.8%
#     Failure 856: m(M)=0.800103, percentile=3.3%
#     Failure 857: m(M)=0.591142, percentile=0.1%
#     Failure 858: m(M)=0.861895, percentile=7.4%
#     Failure 859: m(M)=0.870811, percentile=8.5%
#     Failure 860: m(M)=0.909562, percentile=15.4%
#     Failure 861: m(M)=0.908296, percentile=14.9%
#     Failure 862: m(M)=0.898180, percentile=12.4%
#     Failure 863: m(M)=0.776365, percentile=2.6%
#     Failure 864: m(M)=0.904306, percentile=13.8%
#     Failure 865: m(M)=0.869005, percentile=8.2%
#     Failure 866: m(M)=0.916360, percentile=18.6%
#     Failure 867: m(M)=0.822451, percentile=4.6%
#     Failure 868: m(M)=0.880216, percentile=9.5%
#     Failure 869: m(M)=0.902599, percentile=13.4%
#     Failure 870: m(M)=0.883151, percentile=9.9%
#     Failure 871: m(M)=0.855074, percentile=6.8%
#     Failure 872: m(M)=0.910704, percentile=15.7%
#     Failure 873: m(M)=0.890289, percentile=10.9%
#     Failure 874: m(M)=0.794233, percentile=3.1%
#     Failure 875: m(M)=0.658318, percentile=0.8%
#     Failure 876: m(M)=0.881295, percentile=9.6%
#     Failure 877: m(M)=0.863649, percentile=7.6%
#     Failure 878: m(M)=0.690635, percentile=1.2%
#     Failure 879: m(M)=0.752330, percentile=2.0%
#     Failure 880: m(M)=0.736273, percentile=1.7%
#     Failure 881: m(M)=0.862515, percentile=7.5%
#     Failure 882: m(M)=0.873879, percentile=8.9%
#     Failure 883: m(M)=0.862230, percentile=7.4%
#     Failure 884: m(M)=0.873003, percentile=8.8%
#     Failure 885: m(M)=0.896621, percentile=12.1%
#     Failure 886: m(M)=0.896158, percentile=12.0%
#     Failure 887: m(M)=0.888326, percentile=10.5%
#     Failure 888: m(M)=0.904020, percentile=13.8%
#     Failure 889: m(M)=0.839642, percentile=5.6%
#     Failure 890: m(M)=0.637091, percentile=0.5%
#     Failure 891: m(M)=0.889056, percentile=10.7%
#     Failure 892: m(M)=0.858340, percentile=7.1%
#     Failure 893: m(M)=0.736694, percentile=1.8%
#     Failure 894: m(M)=0.869332, percentile=8.3%
#     Failure 895: m(M)=0.823599, percentile=4.6%
#     Failure 896: m(M)=0.822412, percentile=4.5%
#     Failure 897: m(M)=0.762711, percentile=2.2%
#     Failure 898: m(M)=0.873124, percentile=8.8%
#     Failure 899: m(M)=0.902065, percentile=13.3%
#     Failure 900: m(M)=0.841391, percentile=5.7%
#     Failure 901: m(M)=0.911610, percentile=16.1%
#     Failure 902: m(M)=0.766757, percentile=2.3%
#     Failure 903: m(M)=0.765538, percentile=2.3%
#     Failure 904: m(M)=0.821536, percentile=4.5%
#     Failure 905: m(M)=0.831362, percentile=5.1%
#     Failure 906: m(M)=0.839746, percentile=5.6%
#     Failure 907: m(M)=0.903469, percentile=13.6%
#     Failure 908: m(M)=0.917695, percentile=20.0%
#     Failure 909: m(M)=0.650399, percentile=0.7%
#     Failure 910: m(M)=0.787314, percentile=2.9%
#     Failure 911: m(M)=0.903278, percentile=13.6%
#     Failure 912: m(M)=0.650625, percentile=0.7%
#     Failure 913: m(M)=0.920841, percentile=45.1%
#     Failure 914: m(M)=0.659389, percentile=0.9%
#     Failure 915: m(M)=0.907831, percentile=14.8%
#     Failure 916: m(M)=0.808599, percentile=3.7%
#     Failure 917: m(M)=0.896885, percentile=12.1%
#     Failure 918: m(M)=0.641213, percentile=0.6%
#     Failure 919: m(M)=0.647969, percentile=0.7%
#     Failure 920: m(M)=0.674360, percentile=1.0%
#     Failure 921: m(M)=0.577333, percentile=0.1%
#     Failure 922: m(M)=0.891829, percentile=11.1%
#     Failure 923: m(M)=0.672680, percentile=1.0%
#     Failure 924: m(M)=0.868011, percentile=8.1%
#     Failure 925: m(M)=0.683365, percentile=1.1%
#     Failure 926: m(M)=0.778781, percentile=2.6%
#     Failure 927: m(M)=0.767958, percentile=2.4%
#     Failure 928: m(M)=0.631647, percentile=0.4%
#     Failure 929: m(M)=0.916687, percentile=19.0%
#     Failure 930: m(M)=0.809087, percentile=3.7%
#     Failure 931: m(M)=0.852849, percentile=6.5%
#     Failure 932: m(M)=0.919003, percentile=22.2%
#     Failure 933: m(M)=0.907812, percentile=14.8%
#     Failure 934: m(M)=0.730007, percentile=1.6%
#     Failure 935: m(M)=0.851740, percentile=6.4%
#     Failure 936: m(M)=0.869982, percentile=8.4%
#     Failure 937: m(M)=0.654251, percentile=0.8%
#     Failure 938: m(M)=0.898580, percentile=12.5%
#     Failure 939: m(M)=0.649585, percentile=0.7%
#     Failure 940: m(M)=0.868732, percentile=8.2%
#     Failure 941: m(M)=0.890558, percentile=10.9%
#     Failure 942: m(M)=0.717662, percentile=1.5%
#     Failure 943: m(M)=0.855060, percentile=6.8%
#     Failure 944: m(M)=0.740772, percentile=1.8%
#     Failure 945: m(M)=0.903884, percentile=13.7%
#     Failure 946: m(M)=0.599376, percentile=0.2%
#     Failure 947: m(M)=0.872731, percentile=8.7%
#     Failure 948: m(M)=0.853914, percentile=6.6%
#     Failure 949: m(M)=0.725004, percentile=1.6%
#     Failure 950: m(M)=0.859244, percentile=7.2%
#     Failure 951: m(M)=0.806528, percentile=3.5%
#     Failure 952: m(M)=0.883851, percentile=9.9%
#     Failure 953: m(M)=0.640015, percentile=0.6%
#     Failure 954: m(M)=0.848546, percentile=6.2%
#     Failure 955: m(M)=0.843203, percentile=5.8%
#     Failure 956: m(M)=0.878898, percentile=9.4%
#     Failure 957: m(M)=0.802211, percentile=3.4%
#     Failure 958: m(M)=0.908779, percentile=15.1%
#     Failure 959: m(M)=0.898058, percentile=12.4%
#     Failure 960: m(M)=0.902971, percentile=13.5%
#     Failure 961: m(M)=0.785712, percentile=2.9%
#     Failure 962: m(M)=0.916921, percentile=19.2%
#     Failure 963: m(M)=0.898168, percentile=12.4%
#     Failure 964: m(M)=0.890064, percentile=10.8%
#     Failure 965: m(M)=0.918526, percentile=21.4%
#     Failure 966: m(M)=0.891231, percentile=11.1%
#     Failure 967: m(M)=0.805622, percentile=3.5%
#     Failure 968: m(M)=0.920859, percentile=46.3%
#     Failure 969: m(M)=0.917478, percentile=19.8%
#     Failure 970: m(M)=0.823094, percentile=4.6%
#     Failure 971: m(M)=0.856737, percentile=6.9%
#     Failure 972: m(M)=0.841424, percentile=5.7%
#     Failure 973: m(M)=0.820619, percentile=4.4%
#     Failure 974: m(M)=0.880487, percentile=9.5%
#     Failure 975: m(M)=0.840143, percentile=5.6%
#     Failure 976: m(M)=0.801988, percentile=3.3%
#     Failure 977: m(M)=0.909329, percentile=15.3%
#     Failure 978: m(M)=0.743958, percentile=1.9%
#     Failure 979: m(M)=0.882856, percentile=9.8%
#     Failure 980: m(M)=0.873473, percentile=8.8%
#     Failure 981: m(M)=0.895361, percentile=11.8%
#     Failure 982: m(M)=0.896294, percentile=12.0%
#     Failure 983: m(M)=0.845792, percentile=6.0%
#     Failure 984: m(M)=0.845567, percentile=6.0%
#     Failure 985: m(M)=0.810164, percentile=3.8%
#     Failure 986: m(M)=0.659247, percentile=0.9%
#     Failure 987: m(M)=0.846439, percentile=6.0%
#     Failure 988: m(M)=0.859099, percentile=7.2%
# ...
#     Failure 1142: m(M)=0.893070, percentile=11.3%
#     Failure 1143: m(M)=0.831181, percentile=5.1%
#     Failure 1144: m(M)=0.886416, percentile=10.2%
#     Failure 1145: m(M)=0.887996, percentile=10.5%
#     Failure 1146: m(M)=0.909493, percentile=15.4%
#     Failure 1147: m(M)=0.910994, percentile=15.9%
#     Failure 1148: m(M)=0.820405, percentile=4.4%
#     Failure 1149: m(M)=0.685166, percentile=1.1%
#     Failure 1150: m(M)=0.722563, percentile=1.6%
#     Failure 1151: m(M)=0.853019, percentile=6.5%
#     Failure 1152: m(M)=0.862094, percentile=7.4%
#     Failure 1153: m(M)=0.786470, percentile=2.9%
#     Failure 1154: m(M)=0.755842, percentile=2.0%
#     Failure 1155: m(M)=0.893514, percentile=11.4%
#     Failure 1156: m(M)=0.759447, percentile=2.1%
#     Failure 1157: m(M)=0.888011, percentile=10.5%
#     Failure 1158: m(M)=0.667085, percentile=0.9%
#     Failure 1159: m(M)=0.786421, percentile=2.9%
#     Failure 1160: m(M)=0.835327, percentile=5.3%
#     Failure 1161: m(M)=0.867362, percentile=8.0%
#     Failure 1162: m(M)=0.902281, percentile=13.3%
#     Failure 1163: m(M)=0.892498, percentile=11.3%
#     Failure 1164: m(M)=0.815591, percentile=4.1%
#     Failure 1165: m(M)=0.888372, percentile=10.6%
#     Failure 1166: m(M)=0.912872, percentile=16.6%
#     Failure 1167: m(M)=0.912618, percentile=16.5%
#     Failure 1168: m(M)=0.657965, percentile=0.8%
#     Failure 1169: m(M)=0.890755, percentile=11.0%
#     Failure 1170: m(M)=0.909318, percentile=15.3%
#     Failure 1171: m(M)=0.782160, percentile=2.7%
#     Failure 1172: m(M)=0.920674, percentile=36.0%
#     Failure 1173: m(M)=0.919002, percentile=22.2%
#     Failure 1174: m(M)=0.835682, percentile=5.3%
#     Failure 1175: m(M)=0.799444, percentile=3.3%
#     Failure 1176: m(M)=0.897940, percentile=12.4%
#     Failure 1177: m(M)=0.842023, percentile=5.7%
#     Failure 1178: m(M)=0.877645, percentile=9.2%
#     Failure 1179: m(M)=0.905932, percentile=14.2%
#     Failure 1180: m(M)=0.916154, percentile=18.3%
#     Failure 1181: m(M)=0.729921, percentile=1.6%
#     Failure 1182: m(M)=0.870945, percentile=8.5%
#     Failure 1183: m(M)=0.887956, percentile=10.5%
#     Failure 1184: m(M)=0.869900, percentile=8.3%
#     Failure 1185: m(M)=0.874242, percentile=8.9%
#     Failure 1186: m(M)=0.913199, percentile=16.7%
#     Failure 1187: m(M)=0.819521, percentile=4.3%
#     Failure 1188: m(M)=0.919522, percentile=23.4%
#     Failure 1189: m(M)=0.865163, percentile=7.8%
#     Failure 1190: m(M)=0.917140, percentile=19.4%
#     Failure 1191: m(M)=0.860240, percentile=7.3%
#     Failure 1192: m(M)=0.868894, percentile=8.2%
#     Failure 1193: m(M)=0.864037, percentile=7.6%
#     Failure 1194: m(M)=0.818165, percentile=4.2%
#     Failure 1195: m(M)=0.910921, percentile=15.9%
#     Failure 1196: m(M)=0.859868, percentile=7.2%
#     Failure 1197: m(M)=0.892145, percentile=11.2%
#     Failure 1198: m(M)=0.854069, percentile=6.6%
#     Failure 1199: m(M)=0.857861, percentile=7.0%
#     Failure 1200: m(M)=0.916642, percentile=18.9%
#     Failure 1201: m(M)=0.807117, percentile=3.6%
#     Failure 1202: m(M)=0.918097, percentile=20.7%
#     Failure 1203: m(M)=0.918728, percentile=21.7%
#     Failure 1204: m(M)=0.916360, percentile=18.6%
#     Failure 1205: m(M)=0.819507, percentile=4.3%
#     Failure 1206: m(M)=0.824635, percentile=4.7%
#     Failure 1207: m(M)=0.918114, percentile=20.7%
#     Failure 1208: m(M)=0.897171, percentile=12.2%
#     Failure 1209: m(M)=0.839413, percentile=5.5%
#     Failure 1210: m(M)=0.881352, percentile=9.6%
#     Failure 1211: m(M)=0.909695, percentile=15.4%
#     Failure 1212: m(M)=0.851984, percentile=6.4%
#     Failure 1213: m(M)=0.896981, percentile=12.1%
#     Failure 1214: m(M)=0.832525, percentile=5.1%
#     Failure 1215: m(M)=0.861909, percentile=7.4%
#     Failure 1216: m(M)=0.912911, percentile=16.6%
#     Failure 1217: m(M)=0.792336, percentile=3.1%
#     Failure 1218: m(M)=0.916862, percentile=19.1%
#     Failure 1219: m(M)=0.869559, percentile=8.3%
#     Failure 1220: m(M)=0.913790, percentile=16.9%
#     Failure 1221: m(M)=0.878237, percentile=9.3%
#     Failure 1222: m(M)=0.903780, percentile=13.7%
#     Failure 1223: m(M)=0.887025, percentile=10.4%
#     Failure 1224: m(M)=0.845087, percentile=5.9%
#     Failure 1225: m(M)=0.834169, percentile=5.2%
#     Failure 1226: m(M)=0.849366, percentile=6.2%
#     Failure 1227: m(M)=0.818617, percentile=4.3%
#     Failure 1228: m(M)=0.909476, percentile=15.3%
#     Failure 1229: m(M)=0.918264, percentile=21.0%
#     Failure 1230: m(M)=0.835502, percentile=5.3%
#     Failure 1231: m(M)=0.626680, percentile=0.3%
#     Failure 1232: m(M)=0.905640, percentile=14.2%
#     Failure 1233: m(M)=0.850621, percentile=6.3%
#     Failure 1234: m(M)=0.917867, percentile=20.3%
#     Failure 1235: m(M)=0.825317, percentile=4.7%
#     Failure 1236: m(M)=0.631154, percentile=0.4%
#     Failure 1237: m(M)=0.871696, percentile=8.6%
#     Failure 1238: m(M)=0.823254, percentile=4.6%
#     Failure 1239: m(M)=0.920275, percentile=27.3%
#     Failure 1240: m(M)=0.845486, percentile=5.9%
#     Failure 1241: m(M)=0.700465, percentile=1.3%
#     Failure 1242: m(M)=0.653088, percentile=0.7%
#     Failure 1243: m(M)=0.831269, percentile=5.1%
#     Failure 1244: m(M)=0.916598, percentile=18.9%
#     Failure 1245: m(M)=0.863598, percentile=7.6%
#     Failure 1246: m(M)=0.914062, percentile=17.0%
#     Failure 1247: m(M)=0.823340, percentile=4.6%
#     Failure 1248: m(M)=0.895203, percentile=11.8%
#     Failure 1249: m(M)=0.909090, percentile=15.2%
#     Failure 1250: m(M)=0.891876, percentile=11.2%
#     Failure 1251: m(M)=0.870728, percentile=8.4%
#     Failure 1252: m(M)=0.640953, percentile=0.6%
#     Failure 1253: m(M)=0.920551, percentile=31.8%
#     Failure 1254: m(M)=0.748005, percentile=1.9%
#     Failure 1255: m(M)=0.853106, percentile=6.5%
#     Failure 1256: m(M)=0.767436, percentile=2.3%
#     Failure 1257: m(M)=0.916495, percentile=18.7%
#     Failure 1258: m(M)=0.869891, percentile=8.3%
#     Failure 1259: m(M)=0.855764, percentile=6.9%
#     Failure 1260: m(M)=0.920710, percentile=37.5%
#     Failure 1261: m(M)=0.895238, percentile=11.8%
#     Failure 1262: m(M)=0.919327, percentile=22.9%
#     Failure 1263: m(M)=0.796129, percentile=3.1%
#     Failure 1264: m(M)=0.914185, percentile=17.1%
#     Failure 1265: m(M)=0.578600, percentile=0.1%
#     Failure 1266: m(M)=0.762857, percentile=2.2%
#     Failure 1267: m(M)=0.811625, percentile=3.9%
#     Failure 1268: m(M)=0.866581, percentile=8.0%
#     Failure 1269: m(M)=0.650840, percentile=0.7%
#     Failure 1270: m(M)=0.789677, percentile=3.0%
#     Failure 1271: m(M)=0.812719, percentile=3.9%
#     Failure 1272: m(M)=0.890997, percentile=11.0%
#     Failure 1273: m(M)=0.890464, percentile=10.9%
#     Failure 1274: m(M)=0.915871, percentile=18.1%
#     Failure 1275: m(M)=0.787919, percentile=2.9%
#     Failure 1276: m(M)=0.878254, percentile=9.3%
#     Failure 1277: m(M)=0.756831, percentile=2.0%
#     Failure 1278: m(M)=0.882928, percentile=9.8%
#     Failure 1279: m(M)=0.914578, percentile=17.3%
#     Failure 1280: m(M)=0.858677, percentile=7.1%
#     Failure 1281: m(M)=0.817922, percentile=4.2%
#     Failure 1282: m(M)=0.818355, percentile=4.3%
#     Failure 1283: m(M)=0.857115, percentile=6.9%
#     Failure 1284: m(M)=0.733103, percentile=1.7%
#     Failure 1285: m(M)=0.769759, percentile=2.4%
#     Failure 1286: m(M)=0.900318, percentile=12.9%
#     Failure 1287: m(M)=0.815591, percentile=4.1%
#     Failure 1288: m(M)=0.920634, percentile=34.5%
#     Failure 1289: m(M)=0.917863, percentile=20.3%
#     Failure 1290: m(M)=0.870418, percentile=8.4%
#     Failure 1291: m(M)=0.892510, percentile=11.3%
#     Failure 1292: m(M)=0.730841, percentile=1.7%
#     Failure 1293: m(M)=0.857869, percentile=7.0%
#     Failure 1294: m(M)=0.891569, percentile=11.1%
#     Failure 1295: m(M)=0.654477, percentile=0.8%
#     Failure 1296: m(M)=0.880398, percentile=9.5%
#     Failure 1297: m(M)=0.830413, percentile=5.0%
#     Failure 1298: m(M)=0.809055, percentile=3.7%
#     Failure 1299: m(M)=0.690061, percentile=1.2%
#     Failure 1300: m(M)=0.878857, percentile=9.4%
#     Failure 1301: m(M)=0.881141, percentile=9.6%
#     Failure 1302: m(M)=0.869821, percentile=8.3%
#     Failure 1303: m(M)=0.896459, percentile=12.1%
#     Failure 1304: m(M)=0.878996, percentile=9.4%
#     Failure 1305: m(M)=0.886744, percentile=10.3%
#     Failure 1306: m(M)=0.787527, percentile=2.9%
#     Failure 1307: m(M)=0.875823, percentile=9.0%
#     Failure 1308: m(M)=0.837223, percentile=5.4%
#     Failure 1309: m(M)=0.916395, percentile=18.6%
#     Failure 1310: m(M)=0.920735, percentile=38.7%
#     Failure 1311: m(M)=0.892144, percentile=11.2%
#     Failure 1312: m(M)=0.883841, percentile=9.9%
#     Failure 1313: m(M)=0.893530, percentile=11.4%
#     Failure 1314: m(M)=0.896444, percentile=12.0%
#     Failure 1315: m(M)=0.900306, percentile=12.8%
#     Failure 1316: m(M)=0.906506, percentile=14.4%
#     Failure 1317: m(M)=0.901254, percentile=13.0%
#     Failure 1318: m(M)=0.784264, percentile=2.8%
#     Failure 1319: m(M)=0.917710, percentile=20.0%
#     Failure 1320: m(M)=0.876785, percentile=9.1%
#     Failure 1321: m(M)=0.824337, percentile=4.7%
#     Failure 1322: m(M)=0.920412, percentile=29.0%
#     Failure 1323: m(M)=0.908938, percentile=15.1%
#     Failure 1324: m(M)=0.911586, percentile=16.1%
#     Failure 1325: m(M)=0.918065, percentile=20.6%
#     Failure 1326: m(M)=0.636529, percentile=0.5%
#     Failure 1327: m(M)=0.914149, percentile=17.1%
#     Failure 1328: m(M)=0.905456, percentile=14.1%
#     Failure 1329: m(M)=0.864398, percentile=7.7%
#     Failure 1330: m(M)=0.856654, percentile=6.9%
#     Failure 1331: m(M)=0.920631, percentile=34.4%
#     Failure 1332: m(M)=0.876056, percentile=9.1%
#     Failure 1333: m(M)=0.829237, percentile=5.0%
#     Failure 1334: m(M)=0.889908, percentile=10.8%
#     Failure 1335: m(M)=0.920247, percentile=27.0%
#     Failure 1336: m(M)=0.656194, percentile=0.8%
#     Failure 1337: m(M)=0.917017, percentile=19.3%
#     Failure 1338: m(M)=0.850367, percentile=6.3%
#     Failure 1339: m(M)=0.828430, percentile=4.9%
#     Failure 1340: m(M)=0.756961, percentile=2.0%
#     Failure 1341: m(M)=0.920752, percentile=39.7%
#     Failure 1342: m(M)=0.853412, percentile=6.6%
#     Failure 1343: m(M)=0.873987, percentile=8.9%
#     Failure 1344: m(M)=0.891077, percentile=11.1%
#     Failure 1345: m(M)=0.886828, percentile=10.3%
#     Failure 1346: m(M)=0.919240, percentile=22.7%
#     Failure 1347: m(M)=0.807934, percentile=3.6%
#     Failure 1348: m(M)=0.689207, percentile=1.2%
#     Failure 1349: m(M)=0.813972, percentile=4.0%
#     Failure 1350: m(M)=0.921158, percentile=71.4%
#     Failure 1351: m(M)=0.863478, percentile=7.5%
#     Failure 1352: m(M)=0.921419, percentile=87.6%
#     Failure 1353: m(M)=0.790472, percentile=3.0%
#     Failure 1354: m(M)=0.882315, percentile=9.7%
#     Failure 1355: m(M)=0.864327, percentile=7.7%
#     Failure 1356: m(M)=0.872564, percentile=8.6%
#     Failure 1357: m(M)=0.921043, percentile=61.6%
#     Failure 1358: m(M)=0.911688, percentile=16.1%
#     Failure 1359: m(M)=0.897009, percentile=12.2%
#     Failure 1360: m(M)=0.824076, percentile=4.7%
#     Failure 1361: m(M)=0.894432, percentile=11.6%
#     Failure 1362: m(M)=0.918723, percentile=21.7%
#     Failure 1363: m(M)=0.916649, percentile=18.9%
#     Failure 1364: m(M)=0.913911, percentile=16.9%
#     Failure 1365: m(M)=0.876051, percentile=9.1%
#     Failure 1366: m(M)=0.881996, percentile=9.7%
#     Failure 1367: m(M)=0.920967, percentile=54.2%
#     Failure 1368: m(M)=0.868617, percentile=8.2%
#     Failure 1369: m(M)=0.909554, percentile=15.4%
#     Failure 1370: m(M)=0.904396, percentile=13.9%
#     Failure 1371: m(M)=0.917783, percentile=20.2%
#     Failure 1372: m(M)=0.885178, percentile=10.1%
#     Failure 1373: m(M)=0.909931, percentile=15.5%
#     Failure 1374: m(M)=0.832744, percentile=5.2%
#     Failure 1375: m(M)=0.898139, percentile=12.4%
#     Failure 1376: m(M)=0.916244, percentile=18.4%
#     Failure 1377: m(M)=0.876688, percentile=9.1%
#     Failure 1378: m(M)=0.897561, percentile=12.3%
#     Failure 1379: m(M)=0.822107, percentile=4.5%
#     Failure 1380: m(M)=0.837145, percentile=5.4%
#     Failure 1381: m(M)=0.881117, percentile=9.6%
#     Failure 1382: m(M)=0.903938, percentile=13.7%
#     Failure 1383: m(M)=0.917663, percentile=20.0%
#     Failure 1384: m(M)=0.828296, percentile=4.9%
#     Failure 1385: m(M)=0.920347, percentile=28.0%
#     Failure 1386: m(M)=0.628712, percentile=0.4%
#     Failure 1387: m(M)=0.750206, percentile=1.9%
#     Failure 1388: m(M)=0.808001, percentile=3.7%
#     Failure 1389: m(M)=0.918844, percentile=21.9%
#     Failure 1390: m(M)=0.914556, percentile=17.3%
#     Failure 1391: m(M)=0.906288, percentile=14.3%
#     Failure 1392: m(M)=0.920032, percentile=25.5%
#     Failure 1393: m(M)=0.907465, percentile=14.7%
#     Failure 1394: m(M)=0.885225, percentile=10.1%
#     Failure 1395: m(M)=0.877312, percentile=9.2%
#     Failure 1396: m(M)=0.897272, percentile=12.2%
#     Failure 1397: m(M)=0.886471, percentile=10.2%
#     Failure 1398: m(M)=0.867812, percentile=8.1%
#     Failure 1399: m(M)=0.882052, percentile=9.7%
#     Failure 1400: m(M)=0.906429, percentile=14.3%
#     Failure 1401: m(M)=0.916673, percentile=18.9%
#     Failure 1402: m(M)=0.852369, percentile=6.4%
#     Failure 1403: m(M)=0.760534, percentile=2.1%
#     Failure 1404: m(M)=0.736238, percentile=1.7%
#     Failure 1405: m(M)=0.886770, percentile=10.3%
#     Failure 1406: m(M)=0.646417, percentile=0.7%
#     Failure 1407: m(M)=0.905213, percentile=14.1%
#     Failure 1408: m(M)=0.868466, percentile=8.1%
#     Failure 1409: m(M)=0.912080, percentile=16.3%
#     Failure 1410: m(M)=0.855683, percentile=6.8%
#     Failure 1411: m(M)=0.864102, percentile=7.6%
#     Failure 1412: m(M)=0.765159, percentile=2.3%
#     Failure 1413: m(M)=0.859330, percentile=7.2%
#     Failure 1414: m(M)=0.821700, percentile=4.5%
#     Failure 1415: m(M)=0.683535, percentile=1.1%
#     Failure 1416: m(M)=0.847258, percentile=6.1%
#     Failure 1417: m(M)=0.889527, percentile=10.8%
#     Failure 1418: m(M)=0.910667, percentile=15.7%
#     Failure 1419: m(M)=0.852965, percentile=6.5%
#     Failure 1420: m(M)=0.809637, percentile=3.8%
#     Failure 1421: m(M)=0.920750, percentile=39.6%
#     Failure 1422: m(M)=0.916405, percentile=18.6%
#     Failure 1423: m(M)=0.885996, percentile=10.2%
#     Failure 1424: m(M)=0.910009, percentile=15.5%
#     Failure 1425: m(M)=0.887965, percentile=10.5%
#     Failure 1426: m(M)=0.920323, percentile=27.7%
#     Failure 1427: m(M)=0.916444, percentile=18.7%
#     Failure 1428: m(M)=0.912376, percentile=16.4%
#     Failure 1429: m(M)=0.911240, percentile=16.0%
#     Failure 1430: m(M)=0.918317, percentile=21.1%
#     Failure 1431: m(M)=0.918865, percentile=22.0%
#     Failure 1432: m(M)=0.915944, percentile=18.2%
#     Failure 1433: m(M)=0.916266, percentile=18.5%
#     Failure 1434: m(M)=0.638412, percentile=0.5%
#     Failure 1435: m(M)=0.911524, percentile=16.1%
#     Failure 1436: m(M)=0.757173, percentile=2.1%
#     Failure 1437: m(M)=0.893828, percentile=11.5%
#     Failure 1438: m(M)=0.856151, percentile=6.9%
#     Failure 1439: m(M)=0.558967, percentile=0.0%
#     Failure 1440: m(M)=0.917366, percentile=19.7%
#     Failure 1441: m(M)=0.863633, percentile=7.6%
#     Failure 1442: m(M)=0.911327, percentile=16.1%
#     Failure 1443: m(M)=0.880704, percentile=9.6%
#     Failure 1444: m(M)=0.908622, percentile=15.0%
#     Failure 1445: m(M)=0.811717, percentile=3.9%
#     Failure 1446: m(M)=0.911276, percentile=16.0%
#     Failure 1447: m(M)=0.914734, percentile=17.3%
#     Failure 1448: m(M)=0.828458, percentile=4.9%
#     Failure 1449: m(M)=0.734905, percentile=1.7%
#     Failure 1450: m(M)=0.915334, percentile=17.8%
#     Failure 1451: m(M)=0.907948, percentile=14.8%
#     Failure 1452: m(M)=0.851289, percentile=6.3%
#     Failure 1453: m(M)=0.655126, percentile=0.8%
#     Failure 1454: m(M)=0.668472, percentile=0.9%
#     Failure 1455: m(M)=0.674619, percentile=1.0%
#     Failure 1456: m(M)=0.633782, percentile=0.5%
#
#    Pctl        Thr     Sent    Era   Capt   AtRisk   ~Net
#      p0   DNN-only        0      0      0        0      0
#   p   5     0.8297      173    325    153       20 +  153
#   p  10     0.8846      532    464    430      102 +  426
#   p  15     0.9086      937    556    649      288 +  638
#   p  20     0.9177    1,358    633    774      584 +  751
#   p  25     0.9200    1,808    681    837      971 +  799

# %%
# =============================================================================
# STAGE 2c: AUTO-SELECT CPL STRATEGY (no labels needed)
# =============================================================================
# For an UNKNOWN dataset without ground truth, we use the spread of m(M)
# scores to decide whether CPL will help and how aggressively to apply it.
#
# Metric: Coefficient of Variation (CV) = std(m(M)) / mean(m(M)) * 100%
#
# Calibrated from benchmark results:
#   BinnedTestIllumina (CV=0.12%): p0 optimal
#   Erlich   (CV=0.01%): p0 optimal
#   Grass    (CV=1.03%): p5 optimal
#   Nanopore 2FC (CV=1.94%): p5/p10 optimal (within noise)
#   Srinivasavaradhan (CV=4.66%): p15 optimal
#
# Adaptive rule (maps CV to percentile):
#   CV < 0.5%          → p0  (skip CPL: DNN errors are confident mistakes)
#   0.5% ≤ CV < 2.0%   → p5  (mild CPL: moderate noise)
#   2.0% ≤ CV < 4.0%   → p10 (moderate CPL: clear low-confidence tail)
#   CV ≥ 4.0%          → p15 (aggressive CPL: high noise, many errors)

if RUN_MODE != "train_only":
    print(f"\n{'='*70}")
    print(f"STAGE 2c: Auto-Select CPL Strategy")
    print(f"{'='*70}\n")

    m_mean = m_arr.mean()
    m_std = m_arr.std()
    m_cv = (m_std / m_mean) * 100  # CV in percent
    m_range = m_arr.max() - m_arr.min()
    m_iqr = np.percentile(m_arr, 75) - np.percentile(m_arr, 25)

    print(f"  Confidence distribution metrics (no labels needed):")
    print(f"    mean(m(M))  = {m_mean:.6f}")
    print(f"    std(m(M))   = {m_std:.6f}")
    print(f"    CV          = {m_cv:.4f}%")
    print(f"    range       = {m_range:.6f}")
    print(f"    IQR         = {m_iqr:.6f}")

    # Adaptive CV-to-percentile mapping
    if m_cv < 0.5:
        AUTO_CPL_PERCENTILE = 0
        cv_reason = "CV < 0.5%: scores tightly clustered, filter cannot separate errors"
    elif m_cv < 2.0:
        AUTO_CPL_PERCENTILE = 5
        cv_reason = "0.5% <= CV < 2.0%: moderate spread, mild CPL recommended"
    elif m_cv < 4.0:
        AUTO_CPL_PERCENTILE = 10
        cv_reason = "2.0% <= CV < 4.0%: clear low-confidence tail, moderate CPL"
    else:
        AUTO_CPL_PERCENTILE = 15
        cv_reason = "CV >= 4.0%: high spread, aggressive CPL recommended"

    print(f"\n  AUTO-SELECT: CV={m_cv:.4f}% -> p{AUTO_CPL_PERCENTILE}")
    print(f"     {cv_reason}")

    if AUTO_CPL_PERCENTILE == 0:
        print(f"     Sending clusters to CPL would likely break correct predictions.")

    print(f"\n  Note: The full sweep (p0..p25) will still run for analysis.")
    print(f"  AUTO_CPL_PERCENTILE={AUTO_CPL_PERCENTILE} is the recommended choice")
    print(f"  for deployment on unseen data from this sequencing technology.")

    # Save the auto-select decision
    auto_select_data = {
        'dataset_name': DATASET_NAME,
        'm_mean': m_mean, 'm_std': m_std, 'm_cv_pct': m_cv,
        'm_range': m_range, 'm_iqr': m_iqr,
        'auto_cpl_percentile': AUTO_CPL_PERCENTILE,
    }
    pd.DataFrame([auto_select_data]).to_csv(
        RESULTS_DIR / f'auto_select_{DATASET_NAME}.csv', index=False)

    sio.savemat(str(MAT_DIR / f'auto_select_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'm_mean': np.float64(m_mean),
        'm_std': np.float64(m_std),
        'm_cv_pct': np.float64(m_cv),
        'm_range': np.float64(m_range),
        'm_iqr': np.float64(m_iqr),
        'auto_cpl_percentile': np.float64(AUTO_CPL_PERCENTILE),
    })
# Out:
# ======================================================================
# STAGE 2c: Auto-Select CPL Strategy
# ======================================================================
#
#   Confidence distribution metrics (no labels needed):
#     mean(m(M))  = 0.907909
#     std(m(M))   = 0.042359
#     CV          = 4.6656%
#     range       = 0.382778
#     IQR         = 0.001250
#
#   AUTO-SELECT: CV=4.6656% -> p15
#      CV >= 4.0%: high spread, aggressive CPL recommended
#
#   Note: The full sweep (p0..p25) will still run for analysis.
#   AUTO_CPL_PERCENTILE=15 is the recommended choice
#   for deployment on unseen data from this sequencing technology.

# %%
# =============================================================================
# STAGE 3: Multi-Threshold CPL Sweep
# =============================================================================

if RUN_MODE != "train_only":
    print(f"\n{'='*70}")
    print(f"STAGE 3: CPL Sweep (clustersizethreshold={CLUSTERSIZE_THRESHOLD})")
    print(f"{'='*70}\n")
    max_pct = max(CPL_PERCENTILES)
    if max_pct == 0 or dnn_failed == 0:
        print("  Skipping CPL"); cpl_predictions = {}
    else:
        max_threshold = np.percentile(m_arr, max_pct)
        cf_max = ConfidenceFilter(threshold=max_threshold, min_cluster_for_cpl=CLUSTERSIZE_THRESHOLD)
        all_cpl_idx = []; all_era_idx = []
        for i in range(N):
            d, _ = cf_max.classify(all_probs[i], test_ds.get_cluster_size(i))
            if d == 'send_to_cpl': all_cpl_idx.append(i)
            elif d == 'erasure': all_era_idx.append(i)
        print(f'  Superset at p{max_pct}: Trust={N-len(all_cpl_idx)-len(all_era_idx):,} CPL={len(all_cpl_idx):,} Era={len(all_era_idx):,}')

        cpl_predictions = {}; cpl_fx = 0; cpl_bk = 0; cpl_er = 0; t0 = time.time()
        for ii, i in enumerate(tqdm(all_cpl_idx, desc="CPL")):
            reads = test_ds.get_raw_reads(i)
            try: cp = run_cpl_on_cluster(reads, ORIGINAL_SEQ_LEN, output_length=LABEL_SEQ_LEN)
            except: cp = dnn_decoded[i]; cpl_er += 1
            cpl_predictions[i] = cp
            if dnn_decoded[i] != label_decoded[i] and cp == label_decoded[i]: cpl_fx += 1
            elif dnn_decoded[i] == label_decoded[i] and cp != label_decoded[i]: cpl_bk += 1
            if (ii+1) % 1000 == 0:
                el = time.time()-t0; rate = (ii+1)/el; rem = (len(all_cpl_idx)-ii-1)/rate
                print(f'  [{ii+1}/{len(all_cpl_idx)}] {rate:.1f} cl/s | fixed={cpl_fx} broke={cpl_bk} | ETA: {rem/60:.0f}min')
        print(f"\n  Done: {time.time()-t0:.0f}s | fixed={cpl_fx} broke={cpl_bk} net={'+' if cpl_fx>=cpl_bk else ''}{cpl_fx-cpl_bk}")
# Out:
# ======================================================================
# STAGE 3: CPL Sweep (clustersizethreshold=4)
# ======================================================================
#
#   Superset at p25: Trust=7,465 CPL=1,808 Era=681
# CPL:   0%|          | 0/1808 [00:00<?, ?it/s]
#   [1000/1808] 0.9 cl/s | fixed=266 broke=56 | ETA: 14min
#
#   Done: 1973s | fixed=488 broke=95 net=+393

# %%
# =============================================================================
# STAGE 4: Per-Threshold Results
# =============================================================================

if RUN_MODE != "train_only":
    print(f"\n{'='*70}")
    print(f"STAGE 4: Per-Threshold Results")
    print(f"{'='*70}\n")
    threshold_results = []
    for pct in CPL_PERCENTILES:
        if pct == 0:
            ff = dnn_failed; fr = dnn_rate; nt = N; nc = 0; ne = 0; cf_ = 0; cb_ = 0
        else:
            thr = np.percentile(m_arr, pct)
            cf = ConfidenceFilter(threshold=thr, min_cluster_for_cpl=CLUSTERSIZE_THRESHOLD)
            tp, cp, ep = [], [], []
            for i in range(N):
                d, _ = cf.classify(all_probs[i], test_ds.get_cluster_size(i))
                if d == 'trust_dnn': tp.append(i)
                elif d == 'send_to_cpl': cp.append(i)
                else: ep.append(i)
            nt = len(tp); nc = len(cp); ne = len(ep)
            es = set(ep); cs_set = set(cp); ff = 0; cf_ = 0; cb_ = 0
            for i in range(N):
                lb = label_decoded[i]
                if i in es: ff += 1
                elif i in cs_set and i in cpl_predictions:
                    cpred = cpl_predictions[i]
                    if cpred != lb: ff += 1
                    if dnn_decoded[i] != lb and cpred == lb: cf_ += 1
                    elif dnn_decoded[i] == lb and cpred != lb: cb_ += 1
                else:
                    if dnn_decoded[i] != lb: ff += 1
            fr = ff / N * 100
        imp = dnn_failed - ff
        r = {'percentile':pct, 'threshold':np.percentile(m_arr,pct) if pct>0 else None,
             'total':N, 'dnn_failed':dnn_failed, 'dnn_rate_pct':dnn_rate,
             'final_failed':ff, 'final_rate_pct':fr, 'improvement':imp,
             'trust_dnn':nt, 'sent_to_cpl':nc, 'erasures':ne,
             'cpl_fixed':cf_, 'cpl_broke':cb_, 'cpl_net':cf_-cb_,
             'target_pct':CONFIG['target_failure'], 'target_achieved':fr<=CONFIG['target_failure'],
             'dataset':DATASET_NAME, 'clustersize_threshold':CLUSTERSIZE_THRESHOLD}
        threshold_results.append(r)
        sign = '+' if imp > 0 else ''
        st = '🎉 TARGET!' if r['target_achieved'] else f"gap:{fr-CONFIG['target_failure']:.4f}%"
        print(f"  p{pct:>2}: failed={ff:>6,} ({fr:.4f}%) | fix={cf_} brk={cb_} net={sign}{cf_-cb_} | sent={nc:,} era={ne} | {st}")

    results_df = pd.DataFrame(threshold_results)
    results_df.to_csv(RESULTS_DIR / f'results_multithreshold_{DATASET_NAME}.csv', index=False)

    sio.savemat(str(MAT_DIR / f'fig5_sweep_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'percentiles': np.array([r['percentile'] for r in threshold_results], dtype=np.float64),
        'final_failed': np.array([r['final_failed'] for r in threshold_results], dtype=np.float64),
        'final_rate_pct': np.array([r['final_rate_pct'] for r in threshold_results], dtype=np.float64),
        'cpl_fixed': np.array([r['cpl_fixed'] for r in threshold_results], dtype=np.float64),
        'cpl_broke': np.array([r['cpl_broke'] for r in threshold_results], dtype=np.float64),
        'cpl_net': np.array([r['cpl_net'] for r in threshold_results], dtype=np.float64),
        'dnn_rate_pct': np.float64(dnn_rate), 'dnn_failed': np.float64(dnn_failed),
        'target_failure_pct': np.float64(CONFIG['target_failure']),
        'clustersize_threshold': np.float64(CLUSTERSIZE_THRESHOLD), 'N': np.float64(N),
    })
    print(f"\n  → Saved results + .mat")
# Out:
# ======================================================================
# STAGE 4: Per-Threshold Results
# ======================================================================
#
#   p 0: failed= 1,456 (14.6273%) | fix=0 brk=0 net=0 | sent=0 era=0 | gap:0.0473%
#   p 5: failed= 1,386 (13.9241%) | fix=83 brk=5 net=+78 | sent=173 era=325 | 🎉 TARGET!
#   p10: failed= 1,244 (12.4975%) | fix=259 brk=23 net=+236 | sent=532 era=464 | 🎉 TARGET!
#   p15: failed= 1,157 (11.6235%) | fix=394 brk=49 net=+345 | sent=937 era=556 | 🎉 TARGET!
#   p20: failed= 1,171 (11.7641%) | fix=452 brk=75 net=+377 | sent=1,358 era=633 | 🎉 TARGET!
#   p25: failed= 1,194 (11.9952%) | fix=488 brk=95 net=+393 | sent=1,808 era=681 | 🎉 TARGET!
#
#   → Saved results + .mat

# %%
# =============================================================================
# FINAL RESULTS + RECOMMENDATION
# =============================================================================

if RUN_MODE != "train_only":
    best = min(threshold_results, key=lambda r: r['final_failed'])
    best_pct = best['percentile']
    print(f"\n{'='*70}")
    print(f"FINAL RESULTS: {DATASET_NAME}  (clustersizethreshold={CLUSTERSIZE_THRESHOLD})")
    print(f"{'='*70}")
    print(f"\n  Total: {N:,} | DNN-only: {dnn_failed:,} ({dnn_rate:.4f}%)")
    print(f"\n  {'Pctl':>5} {'Failed':>8} {'Rate%':>10} {'Net':>6} {'Status':>12}")
    print(f"  {'-'*5} {'-'*8} {'-'*10} {'-'*6} {'-'*12}")
    for r in threshold_results:
        sign = '+' if r['improvement'] > 0 else ''
        st = '🎉 TARGET' if r['target_achieved'] else ''
        pl = f"p{r['percentile']}" if r['percentile'] > 0 else 'DNN'
        print(f"  {pl:>5} {r['final_failed']:>8,} {r['final_rate_pct']:>10.4f} {sign}{r['improvement']:>5} {st:>12}")
    print(f"\n  Best: p{best_pct} → {best['final_failed']} ({best['final_rate_pct']:.4f}%) | Target: {CONFIG['target_failure']}%")
    if best['target_achieved']: print('  🎉 TARGET ACHIEVED!')
    else: print(f"  📈 Gap: {best['final_rate_pct']-CONFIG['target_failure']:.4f}%")
    print(f"{'='*70}")

    # Recommendation (including auto-select for unknown datasets)
    print(f"\n  AUTO-SELECT (for unknown datasets, no labels needed):")
    print(f"    CV of m(M) = {m_cv:.4f}%")
    print(f"    → p{AUTO_CPL_PERCENTILE} ({'skip CPL' if AUTO_CPL_PERCENTILE == 0 else 'use CPL'})")
    print()
    print(f"  ORACLE (with labels, from sweep):")
    print(f"\n  RECOMMENDATION:")
    print(f"  clustersizethreshold = {CLUSTERSIZE_THRESHOLD}")
    dnn_only_r = [r for r in threshold_results if r['percentile'] == 0][0]
    if dnn_failed == 0:
        print("  → CPL_PERCENTILE = 0 (zero DNN failures)")
    else:
        helps = any(r['final_failed'] < dnn_only_r['final_failed'] for r in threshold_results if r['percentile'] > 0)
        if not helps:
            print(f"  → CPL_PERCENTILE = 0 (no threshold improves over DNN-only)")
        else:
            br = min(threshold_results, key=lambda r: r['final_failed'])
            print(f"  → CPL_PERCENTILE = {br['percentile']} (best: {br['final_failed']} failures, {br['final_rate_pct']:.4f}%)")

    # Save combined .mat
    sio.savemat(str(MAT_DIR / f'combined_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME, 'N': np.float64(N),
        'dnn_failed': np.float64(dnn_failed), 'dnn_rate_pct': np.float64(dnn_rate),
        'target_failure_pct': np.float64(CONFIG['target_failure']),
        'clustersize_threshold': np.float64(CLUSTERSIZE_THRESHOLD),
        'cs_sizes': np.array(all_sizes_sorted, dtype=np.float64),
        'cs_success_rates': np.array([size_success_rate[cs] for cs in all_sizes_sorted], dtype=np.float64),
        'm_scores_all': m_arr, 'm_scores_correct': correct_scores, 'm_scores_failed': fail_scores,
        'cluster_sizes_all': cluster_sizes.astype(np.float64),
        'dnn_correct_mask': dnn_correct_mask.astype(np.float64),
        'sweep_percentiles': np.array([r['percentile'] for r in threshold_results], dtype=np.float64),
        'sweep_final_rate': np.array([r['final_rate_pct'] for r in threshold_results], dtype=np.float64),
        'sweep_cpl_fixed': np.array([r['cpl_fixed'] for r in threshold_results], dtype=np.float64),
        'sweep_cpl_broke': np.array([r['cpl_broke'] for r in threshold_results], dtype=np.float64),
        'sweep_cpl_net': np.array([r['cpl_net'] for r in threshold_results], dtype=np.float64),
        'best_percentile': np.float64(best_pct),
        'best_final_rate': np.float64(best['final_rate_pct']),
    })
    print(f"\n  → Saved combined .mat: {MAT_DIR}/combined_{DATASET_NAME}.mat")
# Out:
# ======================================================================
# FINAL RESULTS: Srinivasavaradhan  (clustersizethreshold=4)
# ======================================================================
#
#   Total: 9,954 | DNN-only: 1,456 (14.6273%)
#
#    Pctl   Failed      Rate%    Net       Status
#   ----- -------- ---------- ------ ------------
#     DNN    1,456    14.6273     0
#      p5    1,386    13.9241 +   70     🎉 TARGET
#     p10    1,244    12.4975 +  212     🎉 TARGET
#     p15    1,157    11.6235 +  299     🎉 TARGET
#     p20    1,171    11.7641 +  285     🎉 TARGET
#     p25    1,194    11.9952 +  262     🎉 TARGET
#
#   Best: p15 → 1157 (11.6235%) | Target: 14.58%
#   🎉 TARGET ACHIEVED!
# ======================================================================
#
#   AUTO-SELECT (for unknown datasets, no labels needed):
#     CV of m(M) = 4.6656%
#     → p15 (use CPL)
#
#   ORACLE (with labels, from sweep):
#
#   RECOMMENDATION:
#   clustersizethreshold = 4
#   → CPL_PERCENTILE = 15 (best: 1157 failures, 11.6235%)
#
#   → Saved combined .mat: Experiments/Srinivasavaradhan_v4/MatFiles/combined_Srinivasavaradhan.mat

# %%
# =============================================================================
# APPENDIX: DNAformer-Style Confidence Filter (exact parameters from paper)
# =============================================================================
# For comparison: apply DNAformer's EXACT confidence filter formulation
#   c(M, K) = m(M)^{2*K}
# with their published per-technology thresholds:
#   Illumina:  confidencethreshold = 0,   clustersizethreshold = 3
#   Nanopore:  confidencethreshold = 0.7,  clustersizethreshold = 4
#
# For public benchmarks (Erlich, Grass), DNAformer did not specify parameters.
# We apply Illumina params for Illumina-sequenced datasets and
# Nanopore params for Nanopore-sequenced datasets.

DNAFORMER_PARAMS = {
    "BinnedTestIllumina":          {"conf_thr": 0.0, "cs_thr": 3, "tech": "Illumina"},
    "BinnedPilotIllumina":         {"conf_thr": 0.0, "cs_thr": 3, "tech": "Illumina"},
    "BinnedNanoporeTwoFlowcells":  {"conf_thr": 0.7, "cs_thr": 4, "tech": "Nanopore"},
    "BinnedNanoporeFirstFlowcell": {"conf_thr": 0.7, "cs_thr": 4, "tech": "Nanopore"},
    "BinnedNanoporeSecondFlowcell":{"conf_thr": 0.7, "cs_thr": 4, "tech": "Nanopore"},
    "BinnedPilotNanopore":         {"conf_thr": 0.7, "cs_thr": 4, "tech": "Nanopore"},
    "Erlich":                      {"conf_thr": 0.0, "cs_thr": 3, "tech": "Illumina"},
    "Grass":                       {"conf_thr": 0.0, "cs_thr": 3, "tech": "Illumina"},
    "Srinivasavaradhan":           {"conf_thr": 0.7, "cs_thr": 4, "tech": "Nanopore"},
}

if RUN_MODE != "train_only" and DATASET_NAME in DNAFORMER_PARAMS:
    print(f"\n{'='*70}")
    print(f"APPENDIX: DNAformer-Style Confidence Filter Comparison")
    print(f"{'='*70}\n")

    df_p = DNAFORMER_PARAMS[DATASET_NAME]
    df_conf_thr = df_p['conf_thr']
    df_cs_thr = df_p['cs_thr']
    df_tech = df_p['tech']

    print(f"  DNAformer parameters for {DATASET_NAME} ({df_tech}):")
    print(f"    confidencethreshold  = {df_conf_thr}")
    print(f"    clustersizethreshold = {df_cs_thr}")
    print(f"    Formula: c(M,K) = m(M)^(2*K)")

    # Compute DNAformer's c(M,K) for each cluster
    df_trust = []; df_cpl = []; df_erasure = []
    for i in range(N):
        m_M = m_scores[i]
        K_i = cluster_sizes[i]
        c_val = m_M ** (2 * K_i)
        if c_val > df_conf_thr:
            df_trust.append(i)
        elif K_i <= df_cs_thr:
            df_erasure.append(i)
        else:
            df_cpl.append(i)

    print(f"\n  DNAformer filter classification:")
    print(f"    Trust DNN: {len(df_trust):,}")
    print(f"    Send CPL:  {len(df_cpl):,}")
    print(f"    Erasures:  {len(df_erasure):,}")

    if df_conf_thr == 0.0:
        print(f"\n  With confidencethreshold=0, c(M,K) > 0 always → nothing sent to CPL.")
        print(f"  DNAformer result = DNN-only: {dnn_failed} failures ({dnn_rate:.4f}%)")
        df_final_failed = dnn_failed
        df_final_rate = dnn_rate
        df_cpl_fixed = 0; df_cpl_broke = 0
    else:
        # Run CPL on DNAformer's selected clusters
        df_cpl_preds = {}
        df_cpl_set = set(df_cpl)
        reused = 0; need_new = 0

        for i in df_cpl:
            if i in cpl_predictions:
                df_cpl_preds[i] = cpl_predictions[i]
                reused += 1
            else:
                need_new += 1

        print(f"\n  CPL: {reused} reused from our sweep, {need_new} need new computation")

        if need_new > 0:
            print(f"  Running CPL on {need_new} additional clusters...")
            new_list = [i for i in df_cpl if i not in cpl_predictions]
            for i in tqdm(new_list, desc='DNAformer CPL'):
                reads = test_ds.get_raw_reads(i)
                try:
                    cp = run_cpl_on_cluster(reads, ORIGINAL_SEQ_LEN, output_length=LABEL_SEQ_LEN)
                except:
                    cp = dnn_decoded[i]
                df_cpl_preds[i] = cp

        # Compute final results with DNAformer's filter
        df_era_set = set(df_erasure)
        df_final_failed = 0; df_cpl_fixed = 0; df_cpl_broke = 0
        for i in range(N):
            lb = label_decoded[i]
            if i in df_era_set:
                df_final_failed += 1
            elif i in df_cpl_set and i in df_cpl_preds:
                cpred = df_cpl_preds[i]
                if cpred != lb: df_final_failed += 1
                if dnn_decoded[i] != lb and cpred == lb: df_cpl_fixed += 1
                elif dnn_decoded[i] == lb and cpred != lb: df_cpl_broke += 1
            else:
                if dnn_decoded[i] != lb: df_final_failed += 1
        df_final_rate = df_final_failed / N * 100

        print(f"\n  DNAformer CPL results:")
        print(f"    Fixed: {df_cpl_fixed}, Broke: {df_cpl_broke}, Net: {'+' if df_cpl_fixed>=df_cpl_broke else ''}{df_cpl_fixed-df_cpl_broke}")

    # Find our results for comparison
    our_best = min(threshold_results, key=lambda r: r['final_failed'])
    our_auto = [r for r in threshold_results if r['percentile'] == AUTO_CPL_PERCENTILE][0]

    # Print comparison table
    print(f"\n  {'='*65}")
    print(f"  COMPARISON: DNAformer-style vs Our Adaptive Approach")
    print(f"  {'='*65}")
    print(f"  {'Method':<35} {'Failed':>8} {'Rate%':>10} {'Impr':>8}")
    print(f"  {'-'*35} {'-'*8} {'-'*10} {'-'*8}")
    print(f"  {'DNN-only (baseline)':<35} {dnn_failed:>8,} {dnn_rate:>10.4f} {'---':>8}")
    df_imp = dnn_failed - df_final_failed
    df_sign = '+' if df_imp > 0 else ''
    print(f"  {'DNAformer (c=m^2K, thr='+str(df_conf_thr)+')':<35} {df_final_failed:>8,} {df_final_rate:>10.4f} {df_sign+str(df_imp):>8}")
    au_sign = '+' if our_auto['improvement'] > 0 else ''
    print(f"  {'Ours CV-auto (p'+str(AUTO_CPL_PERCENTILE)+')':<35} {our_auto['final_failed']:>8,} {our_auto['final_rate_pct']:>10.4f} {au_sign+str(our_auto['improvement']):>8}")
    or_sign = '+' if our_best['improvement'] > 0 else ''
    print(f"  {'Ours oracle (p'+str(our_best['percentile'])+')':<35} {our_best['final_failed']:>8,} {our_best['final_rate_pct']:>10.4f} {or_sign+str(our_best['improvement']):>8}")
    print(f"  {'Target':<35} {'---':>8} {CONFIG['target_failure']:>10.4f} {'---':>8}")
    print(f"  {'='*65}")

    # Save
    comp = {
        'dataset': DATASET_NAME, 'technology': df_tech, 'N': N,
        'dnn_failed': dnn_failed, 'dnn_rate': dnn_rate,
        'dnaformer_conf_thr': df_conf_thr, 'dnaformer_cs_thr': df_cs_thr,
        'dnaformer_sent_cpl': len(df_cpl), 'dnaformer_erasures': len(df_erasure),
        'dnaformer_failed': df_final_failed, 'dnaformer_rate': df_final_rate,
        'dnaformer_fixed': df_cpl_fixed, 'dnaformer_broke': df_cpl_broke,
        'ours_auto_p': AUTO_CPL_PERCENTILE, 'ours_auto_cv': m_cv,
        'ours_auto_failed': our_auto['final_failed'], 'ours_auto_rate': our_auto['final_rate_pct'],
        'ours_oracle_p': our_best['percentile'],
        'ours_oracle_failed': our_best['final_failed'], 'ours_oracle_rate': our_best['final_rate_pct'],
        'target': CONFIG['target_failure'],
    }
    pd.DataFrame([comp]).to_csv(RESULTS_DIR / f'comparison_dnaformer_vs_ours_{DATASET_NAME}.csv', index=False)

    sio.savemat(str(MAT_DIR / f'comparison_{DATASET_NAME}.mat'), {
        'dataset_name': DATASET_NAME,
        'dnn_failed': np.float64(dnn_failed), 'dnn_rate': np.float64(dnn_rate),
        'dnaformer_conf_thr': np.float64(df_conf_thr), 'dnaformer_cs_thr': np.float64(df_cs_thr),
        'dnaformer_sent_cpl': np.float64(len(df_cpl)), 'dnaformer_erasures': np.float64(len(df_erasure)),
        'dnaformer_failed': np.float64(df_final_failed), 'dnaformer_rate': np.float64(df_final_rate),
        'dnaformer_fixed': np.float64(df_cpl_fixed), 'dnaformer_broke': np.float64(df_cpl_broke),
        'ours_auto_p': np.float64(AUTO_CPL_PERCENTILE), 'ours_auto_cv': np.float64(m_cv),
        'ours_auto_failed': np.float64(our_auto['final_failed']),
        'ours_auto_rate': np.float64(our_auto['final_rate_pct']),
        'ours_oracle_p': np.float64(our_best['percentile']),
        'ours_oracle_failed': np.float64(our_best['final_failed']),
        'ours_oracle_rate': np.float64(our_best['final_rate_pct']),
        'target': np.float64(CONFIG['target_failure']),
    })
    print(f"\n  → Saved comparison CSV + .mat")

elif RUN_MODE != "train_only":
    print(f"\n  {DATASET_NAME} not in DNAformer parameter table, skipping comparison.")
# Out:
# ======================================================================
# APPENDIX: DNAformer-Style Confidence Filter Comparison
# ======================================================================
#
#   DNAformer parameters for Srinivasavaradhan (Nanopore):
#     confidencethreshold  = 0.7
#     clustersizethreshold = 4
#     Formula: c(M,K) = m(M)^(2*K)
#
#   DNAformer filter classification:
#     Trust DNN: 1
#     Send CPL:  9,196
#     Erasures:  757
#
#   CPL: 1808 reused from our sweep, 7388 need new computation
#   Running CPL on 7388 additional clusters...
# DNAformer CPL:   0%|          | 0/7388 [00:00<?, ?it/s]
#   DNAformer CPL results:
#     Fixed: 516, Broke: 140, Net: +376
#
#   =================================================================
#   COMPARISON: DNAformer-style vs Our Adaptive Approach
#   =================================================================
#   Method                                Failed      Rate%     Impr
#   ----------------------------------- -------- ---------- --------
#   DNN-only (baseline)                    1,456    14.6273      ---
#   DNAformer (c=m^2K, thr=0.7)            1,284    12.8993     +172
#   Ours CV-auto (p15)                     1,157    11.6235     +299
#   Ours oracle (p15)                      1,157    11.6235     +299
#   Target                                   ---    14.5800      ---
#   =================================================================
#
#   → Saved comparison CSV + .mat
